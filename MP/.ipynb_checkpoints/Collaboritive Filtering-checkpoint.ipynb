# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path
import urllib.parse

from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Loading Animelist

# %%
df_AnimeList = pd.DataFrame()
for f in list(Path('../Scraping/Season').rglob('*.csv')):
    if re.search(r'.ipynb_checkpoints', str(f)) is not None:
        continue

    df_Read = pd.read_csv(f)
    df_AnimeList = pd.concat([df_AnimeList, df_Read])

del df_Read

# %%
df_AnimeList['MAL_id'] = df_AnimeList['Link'].apply(lambda x : int(re.findall(r'anime/(\d+)',x)[0]))
df_AnimeList = df_AnimeList.drop(columns=['Link', 'Unnamed: 0'])
df_AnimeList = df_AnimeList.set_index('MAL_id')
df_AnimeList = df_AnimeList.drop_duplicates()
df_AnimeList
# Out:
#                                                   Title
# MAL_id
# 30                                 Shinseiki Evangelion
# 852                                  Gokinjo Monogatari
# 495                                   Bakuretsu Hunters
# 1567                                  Kaitou Saint Tail
# 116                      Shinpi no Sekai El-Hazard (TV)
# ...                                                 ...
# 54145           Cardfight!! Vanguard: D Series Season 9
# 53722                                     Bullet/Bullet
# 60726                                My Melody & Kuromi
# 60778   Fushigi no Kuni de Alice to: Dive in Wonderland
# 55779                                            Cocoon
#
# [16261 rows x 1 columns]

# %% [markdown]
# ### Loading User Ratings

# %%
df_Raw = pd.DataFrame()
for f in list(Path('../Scraping/Users/Watchlist').rglob('*.csv')):
    if re.search(r'.ipynb_checkpoints', str(f)) is not None:
        continue

    df_Read = pd.read_csv(f)
    df_Read['User'] = f.name.replace('.csv', '')
    df_Raw = pd.concat([df_Raw, df_Read])

del df_Read

# %%
df_Raw = df_Raw.drop(columns=['Unnamed: 0'])
df_Raw = df_Raw.dropna()

df_Raw['MAL_id'] = df_Raw['MAL_id'].astype(int)
df_Raw['Title'] = df_Raw['Title'].apply(lambda x : urllib.parse.unquote(x).replace('_', ' '))
df_Raw
# Out:
#     MAL_id                                 Title  Score     Type  \
# 2     1735                    Naruto  Shippuuden    9.0       TV
# 5     8481                Bungaku Shoujo Memoire    8.0      OVA
# 6     5525                              07-Ghost   10.0       TV
# 7     1689                 Byousoku 5 Centimeter    9.0    Movie
# 8     3210                 Ikoku Irokoi Romantan    8.0      OVA
# ..     ...                                   ...    ...      ...
# 15   19815                       No Game No Life   10.0       TV
# 16   24991              No Game No Life Specials   10.0  Special
# 17   33674                 No Game No Life  Zero    9.0    Movie
# 18   37402  No Game No Life  Zero - Manner Movie   10.0    Movie
# 19   37585                     Yarichin☆Bitch-bu    8.0      OVA
#
#               User
# 2         -Ari_Su-
# 5         -Ari_Su-
# 6         -Ari_Su-
# 7         -Ari_Su-
# 8         -Ari_Su-
# ..             ...
# 15  ____hentxi____
# 16  ____hentxi____
# ...

# %% [markdown]
# ### User-Anime Score Matrix

# %%
matrix_Raw = df_Raw.pivot_table(index='User', columns='MAL_id', values='Score', aggfunc='mean')
matrix_Raw = matrix_Raw.fillna(0)
matrix_Raw = matrix_Raw.astype(np.int8)
matrix_Raw
# Out:
# MAL_id           1      5      6      7      8      15     16     17     \
# User
# -Ari_Su-             0      0      0      5      0      0      0      0
# -Ellisson-           8      0      0      0      0      0      0      0
# -HonokaKousaka-      0      0      0      0      0      0      0      0
# -Lofn-               8      0      5      0      0      0      0      0
# -Mayu                0      0      0      0      0      0      0      0
# ...                ...    ...    ...    ...    ...    ...    ...    ...
# zilch16              5      0      0      7      0      9      0      0
# zoooper              0      0      0      0      0      0      0      0
# zororonoa            0      0      0      0      0      0      0      0
# zwrei                0      0      0      0      0      0      0      0
# zzombgrl             0      0      0      0      0      0      0      0
#
# MAL_id           18     19     ...  60629  60662  60666  60725  60736  60749  \
# ...

# %% [markdown]
# ### User-User Similarity Matrix

# %%
matrix_Users = pd.DataFrame(cosine_similarity(matrix_Raw), index=matrix_Raw.index, columns=matrix_Raw.index)
matrix_Users.head(10)
# Out:
# User             -Ari_Su-  -Ellisson-  -HonokaKousaka-    -Lofn-     -Mayu  \
# User
# -Ari_Su-         1.000000    0.179281         0.185241  0.271223  0.240850
# -Ellisson-       0.179281    1.000000         0.318937  0.260775  0.225429
# -HonokaKousaka-  0.185241    0.318937         1.000000  0.223382  0.210315
# -Lofn-           0.271223    0.260775         0.223382  1.000000  0.193777
# -Mayu            0.240850    0.225429         0.210315  0.193777  1.000000
# -Norza-          0.090317    0.262912         0.198153  0.175935  0.098186
# -PJ-             0.121379    0.191138         0.208382  0.137197  0.204495
# -R2J-            0.242395    0.303642         0.238033  0.317377  0.209410
# -Trinody-        0.230445    0.222723         0.238584  0.289033  0.231688
# -Xythus-         0.239614    0.371772         0.349097  0.277247  0.265812
#
# User              -Norza-      -PJ-     -R2J-  -Trinody-  -Xythus-  ...  \
# ...

# %% [markdown]
# ## Test User Actual_Hana
# Gather Top 10 Most Similar Users

# %%
USER = 'Actual_Hana'

similar_users = matrix_Users.loc[USER].sort_values(ascending=False)[1:11]
similar_users
# Out:
# User
# _Mei_           0.407530
# jasmine_kb08    0.392706
# xiuzuki         0.385509
# MysticMira      0.374602
# Akachin69       0.373102
# Satoshiwa       0.371323
# rururaruri      0.370735
# gellai          0.365401
# DogAlchemist    0.363518
# lunatricks      0.362840
# Name: Actual_Hana, dtype: float64

# %% [markdown]
# ## Shows User Watched. Others have Watched Some

# %%
alreadyWatched = matrix_Raw.loc[USER] > 0
matrix_Raw.loc[np.append(USER, similar_users.index), alreadyWatched]
# Out:
# MAL_id        20     22     121    123    226    270    355    356    384    \
# User
# Actual_Hana      10      9     10     10      9      9      9      9     10
# _Mei_             0      0      9      0      0      9      0      7      0
# jasmine_kb08      0      0      0      7      7      0      7      6      0
# xiuzuki          10      0      6      0      0      0     10      0      0
# MysticMira        4      0      0      0      0      0      0      0      0
# Akachin69        10      0      0      0      7      7      0      0      0
# Satoshiwa         8      0      0      0      0      0      4      0      0
# rururaruri        9      0      0      0      0      0      0      0      0
# gellai            0      0      0      0      4      0      0      0      0
# DogAlchemist      8      0      0      0      7      0      0      7      8
# lunatricks        0      0      0      0      2      0     10      0      0
#
# ...

# %% [markdown]
# ## Shows User hasn't Watched. Others have

# %%
matrix_Other_User_Ratings = matrix_Raw.loc[similar_users.index, ~alreadyWatched]
matrix_Other_User_Ratings
# Out:
# MAL_id        1      5      6      7      8      15     16     17     18     \
# User
# _Mei_             0      0      0      0      0      0      0      0      0
# jasmine_kb08      5      0      0      0      0      0      0      0      0
# xiuzuki           0      0      0      0      0      0      0      0      0
# MysticMira        0      0      0      0      0      0      0      0      0
# Akachin69         0      0      0      0      0      0      0      0      0
# Satoshiwa         0      0      0      0      0      0      0      0      0
# rururaruri        0      0      0      0      0      0      0      0      0
# gellai            0      0      0      0      0      0      0      0      0
# DogAlchemist      0      0      0      0      0      0      0      0      0
# lunatricks        0      0      0      0      0      0      0      0      0
#
# MAL_id        19     ...  60629  60662  60666  60725  60736  60749  60772  \
# User                 ...
# ...

# %% [markdown]
# ### Recommendations' Avg Score by Similar Users

# %%
reccomended_Shows = matrix_Other_User_Ratings.mean(axis=0).sort_values(ascending=False)[:10]
df_Reccomendations = df_AnimeList.loc[reccomended_Shows.index].copy()
df_Reccomendations['Avg_Score'] = reccomended_Shows.values
df_Reccomendations
# Out:
#                                                     Title  Avg_Score
# MAL_id
# 11111                                             Another        8.4
# 7054                                Kaichou wa Maid-sama!        7.0
# 9919                                       Ao no Exorcist        6.7
# 6702                                           Fairy Tail        6.5
# 4181                                 Clannad: After Story        6.1
# 14741                      Chuunibyou demo Koi ga Shitai!        5.8
# 9989    Ano Hi Mita Hana no Namae wo Bokutachi wa Mada...        5.7
# 13601                                         Psycho-Pass        5.0
# 30276                                       One Punch Man        5.0
# 14813   Yahari Ore no Seishun Love Comedy wa Machigatt...        4.8

# %%
def GetPersonalTop(USER, n = 10):
    USER_top = matrix_Raw.loc[USER].sort_values(ascending=False)[:n]
    
    if USER_top.index.isin(df_AnimeList.index).all():
        df = df_AnimeList.loc[USER_top.index].copy()
    else:
        df = df_Raw[['MAL_id', 'Title']].copy().set_index('MAL_id').loc[USER_top.index].drop_duplicates()
    
    df['Personal_Score'] = USER_top.values
    df = df.rename(columns={'Title': f"{USER}'s Top {n}"})
    return df

    
def Recommend(USER, n = 10):
    similar_users = matrix_Users.loc[USER].sort_values(ascending=False)[1:n+1]
    alreadyWatched = matrix_Raw.loc[USER] > 0
    matrix_Other_User_Ratings = matrix_Raw.loc[similar_users.index, ~alreadyWatched]

    reccomended_Shows = matrix_Other_User_Ratings.mean(axis=0).sort_values(ascending=False)[:n]

    if reccomended_Shows.index.isin(df_AnimeList.index).all():
        df = df_AnimeList.loc[reccomended_Shows.index].copy()
    else:
        df = df_Raw[['MAL_id', 'Title']].copy().set_index('MAL_id').loc[reccomended_Shows.index].drop_duplicates()
        
    df['Avg_Recommenders_Score'] = reccomended_Shows.values
    df = df.rename(columns={'Title': f"Others' Top {n}"})
        
    return df

# %% [markdown]
# ## Test Mainstream Viewer

# %%
USER = '-Norza-'
pd.concat([GetPersonalTop(USER).reset_index(), Recommend(USER).reset_index()], axis=1)
# Out:
#    MAL_id                                   -Norza-'s Top 10  Personal_Score  \
# 0   16498                                 Shingeki no Kyojin              10
# 1   39547  Yahari Ore no Seishun Love Comedy wa Machigatt...              10
# 2   23847  Yahari Ore no Seishun Love Comedy wa Machigatt...              10
# 3     578                                     Hotaru no Haka              10
# 4   31240              Re Zero kara Hajimeru Isekai Seikatsu              10
# 5   34134                           One Punch Man 2nd Season              10
# 6   32281                                      Kimi no Na wa              10
# 7   38040  Kono Subarashii Sekai ni Shukufuku wo Movie  K...              10
# 8   40456           Kimetsu no Yaiba Movie  Mugen Ressha-hen              10
# 9   42203  Re Zero kara Hajimeru Isekai Seikatsu 2nd Seas...              10
#
#    MAL_id                                     Others' Top 10  \
# ...

# %% [markdown]
# ## Test Watched Only One Punch Man (Cold Start)

# %%
USER = 'EXUPUROOOSHUN'
pd.concat([GetPersonalTop(USER).reset_index(), Recommend(USER).reset_index()], axis=1)
# Out:
#    MAL_id           EXUPUROOOSHUN's Top 10  Personal_Score  MAL_id  \
# 0   30276                    One Punch Man              10   32281
# 1       1                     Cowboy Bebop               0   28851
# 2   34925                Butten Monogatari               0   31240
# 3   34899                    Monmusu Quest               0   22319
# 4   34901               Beyblade Burst God               0   18679
# 5   34902               Tsurezure Children               0     185
# 6   34903  RoboMasters the Animated Series               0   28121
# 7   34904     Youjo Senki  Senkyou Houkoku               0    2002
# 8   34907              Through the Windows               0    5040
# 9   34914                         New Game               0   27631
#
#                                       Others' Top 10  Avg_Recommenders_Score
# 0                                     Kimi no Na wa.                     1.9
# ...

# %% [markdown]
# ## Test Max Ranker : Everything 10

# %%
USER = 'Muhclis'
pd.concat([GetPersonalTop(USER,100).reset_index(), Recommend(USER,100).reset_index()], axis=1)
# Out:
#     MAL_id                                  Muhclis's Top 100  Personal_Score  \
# 0    10686  Naruto: Honoo no Chuunin Shiken! Naruto vs. Ko...              10
# 1    51180  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...              10
# 2     7612                                         Haha Sange              10
# 3    51088                                           Eroriman              10
# 4    51096  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...              10
# ..     ...                                                ...             ...
# 95   31933  JoJo no Kimyou na Bouken Part 4: Diamond wa Ku...              10
# 96   50307                         Tonikaku Kawaii 2nd Season              10
# 97    8110                   Fukubiki! Triangle: Miharu After              10
# 98   50336  Nudist Beach ni Shuugaku Ryokou de!! The Anima...              10
# 99   40748                                     Jujutsu Kaisen              10
#
# ...

# %% [markdown]
# ## AOT Fan

# %%
USER = 'Math082r'
pd.concat([GetPersonalTop(USER).reset_index(), Recommend(USER).reset_index()], axis=1)
# Out:
#    MAL_id                                  Math082r's Top 10  Personal_Score  \
# 0    2251                                           Baccano!              10
# 1   28851                                     Koe no Katachi              10
# 2   59571  Shingeki no Kyojin Movie: Kanketsu-hen - The L...               9
# 3   48583        Shingeki no Kyojin: The Final Season Part 2               9
# 4    3297                               Aria the Origination               9
# 5    4181                               Clannad: After Story               9
# 6   40028               Shingeki no Kyojin: The Final Season               9
# 7   51535  Shingeki no Kyojin: The Final Season - Kankets...               9
# 8   50183                                         Blue Giant               8
# 9    5081                                     Bakemonogatari               8
#
#    MAL_id                                     Others' Top 10  \
# ...

# %% [markdown]
# ## Drama/Seinnen/Character Growth (Monogatari / Garden of Sinners / Vinland S2)

# %%
USER = 'Shizawari'
pd.concat([GetPersonalTop(USER, 15).reset_index(), Recommend(USER, 15).reset_index()], axis=1)
# Out:
#     MAL_id                                 Shizawari's Top 15  Personal_Score  \
# 0    55016                                               Idol              10
# 1     4282               Kara no Kyoukai Movie 5  Mujun Rasen              10
# 2    11597                                     Nisemonogatari              10
# 3    50416                                     Skip to Loafer              10
# 4    33352                                  Violet Evergarden              10
# 5    37105                                         Grand Blue              10
# 6    52991                                  Sousou no Frieren              10
# 7     5205      Kara no Kyoukai Movie 7  Satsujin Kousatsu Go              10
# 8    33050  Fate stay night Movie  Heavens Feel - III Spri...              10
# 9    51479                                             Gunjou              10
# 10   53998         Bleach  Sennen Kessen-hen - Ketsubetsu-tan              10
# ...

# %% [markdown]
# ## Gooner

# %%
USER = 'omanko1'
pd.concat([GetPersonalTop(USER).reset_index(), Recommend(USER).reset_index()], axis=1)
# Out:
#    MAL_id                                   omanko1's Top 10  Personal_Score  \
# 0   59119                                             Imaria              10
# 1   50192                        Akane wa Tsumare Somerareru              10
# 2   49295                        Chizuru-chan Kaihatsu Nikki              10
# 3   59407   Iribitari Gal ni Ma〇ko Tsukawasete Morau Hanashi               9
# 4   48468  Uchi no Otouto Maji de Dekain Dakedo Mi ni Konai?               9
# 5   39530                  Ecchi na Oneechan ni Shiboraretai               9
# 6   32587                                      Shoujo Ramune               9
# 7   22429                                   Itadaki! Seieki♥               9
# 8   55850     Tsuma ni Damatte Sokubaikai ni Ikun ja Nakatta               9
# 9   55146                        Kunoichi Ryoujokuden Ajisai               9
#
#    MAL_id                                     Others' Top 10  \
# ...

# %% [markdown]
# # Review
# Compared to content based, this method feels more like a black box approach.
#
# It relies on the shrared ratings between users that will often be difficult to visually interpret considering the matrix's size. More than that, most of what is recommended is Mainstream due to majority ruling.
#
# The only most notable distinction we could make was that a Porn viewer is correctly recommendeded explicit content from other users.

# %% [markdown]
# # Item-Item Approach

# %%
matrix_Anime = pd.DataFrame(cosine_similarity(matrix_Raw.T), index=matrix_Raw.columns, columns=matrix_Raw.columns)
matrix_Anime.head()
# Out:
# MAL_id     1         5         6         7         8         15        16     \
# MAL_id
# 1       1.000000  0.558955  0.386905  0.240997  0.135340  0.226431  0.241048
# 5       0.558955  1.000000  0.388967  0.185751  0.094317  0.165831  0.197267
# 6       0.386905  0.388967  1.000000  0.306710  0.182908  0.256733  0.188511
# 7       0.240997  0.185751  0.306710  1.000000  0.177070  0.105195  0.199474
# 8       0.135340  0.094317  0.182908  0.177070  1.000000  0.223785  0.119618
#
# MAL_id     17        18        19     ...  60629  60662  60666  60725  \
# MAL_id                                ...
# 1       0.181897  0.249274  0.414029  ...    0.0    0.0    0.0    0.0
# 5       0.189277  0.221777  0.315651  ...    0.0    0.0    0.0    0.0
# 6       0.185654  0.270443  0.269966  ...    0.0    0.0    0.0    0.0
# 7       0.309352  0.225772  0.107800  ...    0.0    0.0    0.0    0.0
# 8       0.259074  0.128604  0.041896  ...    0.0    0.0    0.0    0.0
#
# ...

# %% [markdown]
# ## Test Harem : Rent a Girlfirend
#
# Expecting Subsequent Seasons + Other harem Anime

# %%
def ReccommendByItem(ANIME_ID : int, n = 10):
    similar_ID = matrix_Anime.loc[ANIME_ID].sort_values(ascending=False)[:n+1]
    return pd.concat([df_Raw.set_index('MAL_id').loc[similar_ID.index]['Title'].drop_duplicates(), similar_ID], axis=1)

# %%
ReccommendByItem(40839)
# Out:
#                                                     Title     40839
# MAL_id
# 40839                                 Kanojo Okarishimasu  1.000000
# 37450   Seishun Buta Yarou wa Bunny Girl Senpai no Yum...  0.595651
# 38101                                5-toubun no Hanayome  0.569610
# 40591   Kaguya-sama wa Kokurasetai Tensai-tachi no Ren...  0.560411
# 39783                              5-toubun no Hanayome ∬  0.557880
# 39535            Mushoku Tensei  Isekai Ittara Honki Dasu  0.556802
# 37999   Kaguya-sama wa Kokurasetai  Tensai-tachi no Re...  0.544399
# 48736                     Sono Bisque Doll wa Koi wo Suru  0.541146
# 39587    Re Zero kara Hajimeru Isekai Seikatsu 2nd Season  0.539585
# 41389                                     Tonikaku Kawaii  0.539480
# 42963                      Kanojo Okarishimasu 2nd Season  0.538204

# %% [markdown]
# ## Test Niche Gambling : Kakegurui
# Expecting shows related to competition.

# %%
ReccommendByItem(34933)
# Out:
#                                                     Title     34933
# MAL_id
# 34933                                           Kakegurui  1.000000
# 37086                                         Kakegurui××  0.764502
# 37999   Kaguya-sama wa Kokurasetai  Tensai-tachi no Re...  0.580343
# 35507     Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e  0.550055
# 35849                               Darling in the FranXX  0.530836
# 38000                                    Kimetsu no Yaiba  0.528418
# 37450   Seishun Buta Yarou wa Bunny Girl Senpai no Yum...  0.524671
# 28851                                      Koe no Katachi  0.521507
# 33352                                   Violet Evergarden  0.519724
# 40591   Kaguya-sama wa Kokurasetai Tensai-tachi no Ren...  0.517046
# 40748                                      Jujutsu Kaisen  0.510352
