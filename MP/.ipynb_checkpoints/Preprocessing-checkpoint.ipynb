# %%
import pandas as pd
import numpy as np
from os import listdir
import re

# %% [markdown]
# # Parsing

# %%
def CompileCSV(FOLDER : str):
    FILENAMES = [f'{FOLDER}/{file}' for file in listdir(FOLDER)[1:]]
    FILENAMES
    
    output = None
    
    for f in FILENAMES:
        if f[-4:] != '.csv':
            break
    
        df = None
    
        YEAR, SEASON = f.split('/')[-1].strip('.csv').split('_')
        #print(YEAR, SEASON)
    
        df = pd.read_csv(f).drop(columns='Unnamed: 0')
        df['Year'] = YEAR
        df['Season'] = SEASON
    
    
        if output is None:
            output = df.copy()
        else:
            output = pd.concat([output, df])

    return output

# %%
df_ids = CompileCSV('../Scraping/Season')
df_ids['MAL_id'] = df_ids.Link.str.extract(r'myanimelist.net/anime/(\d+)').astype(int)
df_ids.head()
# Out:
#                             Title  \
# 0            Shinseiki Evangelion
# 1              Gokinjo Monogatari
# 2               Bakuretsu Hunters
# 3               Kaitou Saint Tail
# 4  Shinpi no Sekai El-Hazard (TV)
#
#                                                 Link  Year Season  MAL_id
# 0  https://myanimelist.net/anime/30/Shinseiki_Eva...  1995   fall      30
# 1  https://myanimelist.net/anime/852/Gokinjo_Mono...  1995   fall     852
# 2  https://myanimelist.net/anime/495/Bakuretsu_Hu...  1995   fall     495
# 3  https://myanimelist.net/anime/1567/Kaitou_Sain...  1995   fall    1567
# 4  https://myanimelist.net/anime/116/Shinpi_no_Se...  1995   fall     116

# %%
df = CompileCSV('../Scraping/Detail/')
df_ids = df_ids.drop_duplicates('MAL_id')
df = pd.merge(df, df_ids[['Title', 'MAL_id']], on='Title', how='left')
df = df.set_index('MAL_id')

df = df.drop(columns=['Synonyms', 'Japanese', 'English', 'German', 'Spanish', 'French', 'Aired','Broadcast','Premiered'])
df.head(3).T
# Out:
# MAL_id                                                        249   \
# Type                                                        ['TV']
# Episodes                                                       167
# Status                                             Finished Airing
# Producers                                  ['Yomiuri Telecasting']
# Licensors                                            ['VIZ Media']
# Studios                                                ['Sunrise']
# Source                                                   ['Manga']
# Genres               ['Action', 'Adventure', 'Fantasy', 'Romance']
# Themes           ['Historical', 'Love Polygon', 'Mythology', 'T...
# Demographic                                            ['Shounen']
# Duration                                           24 min. per ep.
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         7.87
# Ranked                                                        #894
# Popularity                                                    #245
# Members                                                    827,227
# Favorites                                                   19,338
# Scorers                                                   402579.0
# Synopsis         Kagome Higurashi's 15th birthday takes a sudde...
# Related_Entries  ['Sequel (TV) InuYasha: Kanketsu-hen', 'Adapta...
# Title                                                     InuYasha
# Genre                                                          NaN
# Theme                                                          NaN
# Demographics                                                   NaN
# Year                                                          2000
# Season                                                        fall
#
# MAL_id                                                        263   \
# Type                                                        ['TV']
# Episodes                                                        75
# Status                                             Finished Airing
# Producers                                                  ['VAP']
# Licensors           ['Discotek Media', 'Geneon Entertainment USA']
# Studios                                               ['Madhouse']
# Source                                                   ['Manga']
# Genres                                                         NaN
# Themes                                                         NaN
# Demographic                                            ['Shounen']
# Duration                                           23 min. per ep.
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         8.78
# Ranked                                                         #37
# Popularity                                                    #359
# Members                                                    638,244
# Favorites                                                   23,544
# Scorers                                                   315401.0
# Synopsis         In his father's absence, teenager Ippo Makunou...
# Related_Entries  ['Sequel (TV Special) Hajime no Ippo: Champion...
# Title                                               Hajime no Ippo
# Genre                                                   ['Sports']
# Theme                                            ['Combat Sports']
# Demographics                                                   NaN
# Year                                                          2000
# Season                                                        fall
#
# MAL_id                                                        1281
# Type                                                        ['TV']
# Episodes                                                        19
# Status                                             Finished Airing
# Producers                                   ['Aniplex', 'Fuji TV']
# Licensors                          ['ADV Films', 'Discotek Media']
# Studios                                                ['Pierrot']
# Source                                                       Novel
# Genres                       ['Horror', 'Mystery', 'Supernatural']
# Themes                                                         NaN
# Demographic                                                    NaN
# Duration                                           24 min. per ep.
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         7.75
# Ranked                                                       #1168
# Popularity                                                   #1118
# Members                                                    233,279
# Favorites                                                    2,280
# Scorers                                                    98486.0
# Synopsis         Years ago, all of the ghosts in a haunted scho...
# Related_Entries                                                 []
# Title                                             Gakkou no Kaidan
# Genre                                                          NaN
# Theme                                                          NaN
# Demographics                                                   NaN
# Year                                                          2000
# Season                                                        fall

# %%
def ExtractList(col : str):
    df[col] = df[col].str.findall(r"'([^']*)'")

for c in ['Producers', 'Licensors', 'Studios', 'Themes', 'Theme', 'Genres', 'Genre', 'Demographics', 'Demographic']:
    ExtractList(c)

# %%
def ExtractFirstItemInList(col : str):
    df[col] = df[col].str.extract(r"'([^']*)'")
    
for c in ['Source', 'Type']:
    ExtractFirstItemInList(c)

# %%
df['Episodes'] = df['Episodes'].replace('Unknown', np.nan).astype(float)

# %%
df['Is_Finished'] = df.Status == 'Finished Airing'
df = df.drop(columns=['Status'])

# %%
ExtractList('Related_Entries')
df['Related_Entries'] = df['Related_Entries'].apply(lambda x : len(x))

# %%
df['Synopsis'] = df['Synopsis'].str.replace(r'\[.*Written.*?\]|\(.*Source.*?\)|^No synopsis information has been added to this title. Help improve our database by adding a synopsis here.', '', regex=True)

# %%
df['Year'] = df['Year'].astype(int)
df['Members'] = df['Members'].replace(',','', regex=True).astype(int)
df['Favorites'] = df['Favorites'].replace(',','', regex=True).astype(int)

# %%
df['Score'] = df['Score'].replace('[]', np.nan).astype(float)

# %%
df['Scorers'] = df['Scorers'].replace(np.nan, 0).astype(int)

# %%
df['Ranked'] = df['Ranked'].replace('#', '', regex=True).astype(float)
df['Popularity'] = df['Popularity'].replace('#', '', regex=True).astype(int)

# %%
df['Themes'] = df['Theme'].combine_first(df['Themes'])
df['Genres'] = df['Genre'].combine_first(df['Genres'])
df['Demographics'] = df['Demographic'].combine_first(df['Demographics'])
df = df.drop(columns=['Theme', 'Genre', 'Demographic'])

# %%
def ExtractMinutes(time_str : str):
    hours_match = re.search(r'(\d+)\s*hr', time_str)
    minutes_match = re.search(r'(\d+)\s*min', time_str)

    minutes = 0
    if hours_match:
        minutes += int(hours_match.group(1)) * 60
    if minutes_match:
        minutes += int(minutes_match.group(1)) 

    return minutes

df['Duration'] = df['Duration'].apply(lambda x: ExtractMinutes(str(x)))

# %%
df.head().T
# Out:
# MAL_id                                                        249   \
# Type                                                            TV
# Episodes                                                     167.0
# Producers                                    [Yomiuri Telecasting]
# Licensors                                              [VIZ Media]
# Studios                                                  [Sunrise]
# Source                                                       Manga
# Genres                       [Action, Adventure, Fantasy, Romance]
# Themes           [Historical, Love Polygon, Mythology, Time Tra...
# Duration                                                        24
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         7.87
# Ranked                                                       894.0
# Popularity                                                     245
# Members                                                     827227
# Favorites                                                    19338
# Scorers                                                     402579
# Synopsis         Kagome Higurashi's 15th birthday takes a sudde...
# Related_Entries                                                  2
# Title                                                     InuYasha
# Demographics                                             [Shounen]
# Year                                                          2000
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                        263   \
# Type                                                            TV
# Episodes                                                      75.0
# Producers                                                    [VAP]
# Licensors               [Discotek Media, Geneon Entertainment USA]
# Studios                                                 [Madhouse]
# Source                                                       Manga
# Genres                                                    [Sports]
# Themes                                             [Combat Sports]
# Duration                                                        23
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         8.78
# Ranked                                                        37.0
# Popularity                                                     359
# Members                                                     638244
# Favorites                                                    23544
# Scorers                                                     315401
# Synopsis         In his father's absence, teenager Ippo Makunou...
# Related_Entries                                                  2
# Title                                               Hajime no Ippo
# Demographics                                             [Shounen]
# Year                                                          2000
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                        1281  \
# Type                                                            TV
# Episodes                                                      19.0
# Producers                                       [Aniplex, Fuji TV]
# Licensors                              [ADV Films, Discotek Media]
# Studios                                                  [Pierrot]
# Source                                                         NaN
# Genres                             [Horror, Mystery, Supernatural]
# Themes                                                         NaN
# Duration                                                        24
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         7.75
# Ranked                                                      1168.0
# Popularity                                                    1118
# Members                                                     233279
# Favorites                                                     2280
# Scorers                                                      98486
# Synopsis         Years ago, all of the ghosts in a haunted scho...
# Related_Entries                                                  0
# Title                                             Gakkou no Kaidan
# Demographics                                                   NaN
# Year                                                          2000
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                        243   \
# Type                                                            TV
# Episodes                                                      13.0
# Producers                                                [Aniplex]
# Licensors                                   [Nozomi Entertainment]
# Studios                                              [Studio Deen]
# Source                                                       Manga
# Genres                                         [Boys Love, Comedy]
# Themes                                [Adult Cast, Music, Showbiz]
# Duration                                                        22
# Rating                                   PG-13 - Teens 13 or older
# Score                                                          6.9
# Ranked                                                      4815.0
# Popularity                                                    1915
# Members                                                     123243
# Favorites                                                     1124
# Scorers                                                      66278
# Synopsis         All Shuichi ever dreamed about was following i...
# Related_Entries                                                  2
# Title                                                  Gravitation
# Demographics                                              [Shoujo]
# Year                                                          2000
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                        180
# Type                                                            TV
# Episodes                                                      13.0
# Producers                             [GDH, Dentsu, Media Factory]
# Licensors                   [Funimation, Geneon Entertainment USA]
# Studios                                                    [Gonzo]
# Source                                                         NaN
# Genres                                     [Action, Sci-Fi, Ecchi]
# Themes                                              [Mecha, Space]
# Duration                                                        22
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         7.15
# Ranked                                                      3630.0
# Popularity                                                    2412
# Members                                                      87637
# Favorites                                                      437
# Scorers                                                      44821
# Synopsis         In Vandread, men are from Mars and women are f...
# Related_Entries                                                  4
# Title                                                     Vandread
# Demographics                                                   NaN
# Year                                                          2000
# Season                                                        fall
# Is_Finished                                                   True

# %%
df.dtypes
# Out:
# Type                object
# Episodes           float64
# Producers           object
# Licensors           object
# Studios             object
# Source              object
# Genres              object
# Themes              object
# Duration             int64
# Rating              object
# Score              float64
# Ranked             float64
# Popularity           int64
# Members              int64
# Favorites            int64
# Scorers              int64
# Synopsis            object
# Related_Entries      int64
# Title               object
# Demographics        object
# Year                 int64
# Season              object
# Is_Finished           bool
# dtype: object

# %%
df.to_csv('Cleaned.csv')

# %% [markdown]
# # Utility Matrix

# %%
def OneHotList(input_df, col, prefix):
    output = input_df[[col]]

    output = output.fillna('FILLNA')
    
    for i in output[col].explode().unique():
        output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)

    if f'{prefix}FILLNA' in output.columns:
        output = output.drop(columns=[f'{prefix}FILLNA'])

    output = output.drop(columns=[col])
    return output

# %%
USM = df[['Title', 'Is_Finished']].copy()
USM['Is_Finished'] = USM['Is_Finished'].astype(np.int8)

items = [('Genres', 'Genre_'),
         ('Demographics', 'Demo_'),
         ('Themes', 'Theme_'),
         ('Studios', 'Studio_'),
         ('Producers', 'Producer_'),
         ('Licensors', 'Licensor_'),
        ]

for i in items:      
    USM = pd.concat(axis=1, objs= [USM, OneHotList(df, i[0], i[1])])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# ...
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17720\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)

# %%
df.loc[40776]
# Out:
# Type                                                              TV
# Episodes                                                        12.0
# Producers          [Dentsu, Mainichi Broadcasting System, Movic, ...
# Licensors                                         [Sentai Filmworks]
# Studios                                             [Production I.G]
# Source                                                         Manga
# Genres                                                      [Sports]
# Themes                                         [School, Team Sports]
# Duration                                                          23
# Rating                                     PG-13 - Teens 13 or older
# Score                                                           8.55
# Ranked                                                         124.0
# Popularity                                                       219
# Members                                                       863774
# Favorites                                                       6318
# Scorers                                                       513859
# Synopsis           Once called a fallen powerhouse and known as "...
# Related_Entries                                                    4
# Title                                    Haikyuu!! To the Top Part 2
# Demographics                                               [Shounen]
# Year                                                            2020
# Season                                                          fall
# Is_Finished                                                     True
# Name: 40776, dtype: object

# %%
items = [
    ['Type', 'Type'],
    ['Rating', 'Rating'],
    ['Source', 'Source'],
]

for i in items:      
    USM = pd.concat(axis=1, objs= [USM, 
                                   pd.get_dummies(df[i[0]], prefix=i[1]).astype(np.int8)])

# %%
USM = pd.concat([USM, df[['Score', 'Members', 'Favorites', 'Related_Entries', 'Year', 'Episodes']]], axis=1)

# %%
USM
# Out:
#                                                     Title  Is_Finished  \
# MAL_id
# 249                                              InuYasha            1
# 263                                        Hajime no Ippo            1
# 1281                                     Gakkou no Kaidan            1
# 243                                           Gravitation            1
# 180                                              Vandread            1
# ...                                                   ...          ...
# 58606         Girls & Panzer: Saishuushou Part 4 Specials            1
# 58006   Science SARU x MBS Original Short Anime Daisak...            1
# 58229                            Harutsugeuo to Fuuraibou            1
# 58605                           Moja to Majo (TV Special)            1
# 58308                         Hakofugu to Minamata no Umi            1
#
#         Genre_Action  Genre_Adventure  Genre_Fantasy  Genre_Romance  \
# MAL_id
# 249                1                1              1              1
# 263                0                0              0              0
# 1281               0                0              0              0
# 243                0                0              0              0
# 180                1                0              0              0
# ...              ...              ...            ...            ...
# 58606              0                0              0              0
# 58006              0                0              0              0
# 58229              0                1              0              0
# 58605              0                0              1              0
# 58308              0                1              1              0
#
#         Genre_Sports  Genre_Horror  Genre_Mystery  Genre_Supernatural  ...  \
# MAL_id                                                                 ...
# 249                0             0              0                   0  ...
# 263                1             0              0                   0  ...
# 1281               0             1              1                   1  ...
# 243                0             0              0                   0  ...
# 180                0             0              0                   0  ...
# ...              ...           ...            ...                 ...  ...
# 58606              0             0              0                   0  ...
# 58006              0             0              0                   0  ...
# 58229              0             0              0                   0  ...
# 58605              0             0              0                   0  ...
# 58308              0             0              0                   0  ...
#
#         Source_4-koma manga  Source_Light novel  Source_Manga  \
# MAL_id
# 249                       0                   0             1
# 263                       0                   0             1
# 1281                      0                   0             0
# 243                       0                   0             1
# 180                       0                   0             0
# ...                     ...                 ...           ...
# 58606                     0                   0             0
# 58006                     0                   0             0
# 58229                     0                   0             0
# 58605                     0                   0             0
# 58308                     0                   0             0
#
#         Source_Web manga  Score  Members  Favorites  Related_Entries  Year  \
# MAL_id
# 249                    0   7.87   827227      19338                2  2000
# 263                    0   8.78   638244      23544                2  2000
# 1281                   0   7.75   233279       2280                0  2000
# 243                    0   6.90   123243       1124                2  2000
# 180                    0   7.15    87637        437                4  2000
# ...                  ...    ...      ...        ...              ...   ...
# 58606                  0   7.29     2956          2                0  2024
# 58006                  0   6.06      538          0                0  2024
# 58229                  0    NaN      232          0                0  2024
# 58605                  0    NaN      113          0                0  2024
# 58308                  0    NaN      105          0                0  2024
#
#         Episodes
# MAL_id
# 249        167.0
# 263         75.0
# 1281        19.0
# 243         13.0
# 180         13.0
# ...          ...
# 58606        2.0
# 58006        4.0
# 58229        1.0
# 58605        1.0
# 58308        1.0
#
# [21970 rows x 2592 columns]

# %%
USM.to_csv('USM.csv')
