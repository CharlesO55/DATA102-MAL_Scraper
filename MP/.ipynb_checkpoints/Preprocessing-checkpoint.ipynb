# %%
import pandas as pd
import numpy as np
from os import listdir
import re

# %% [markdown]
# # Parsing

# %%
def CompileCSV(FOLDER : str):
    FILENAMES = [f'{FOLDER}/{file}' for file in listdir(FOLDER)[1:]]
    FILENAMES
    
    output = None
    
    for f in FILENAMES:
        if f[-4:] != '.csv':
            break
    
        df = None
    
        YEAR, SEASON = f.split('/')[-1].strip('.csv').split('_')
        #print(YEAR, SEASON)
    
        df = pd.read_csv(f).drop(columns='Unnamed: 0')
        df['Year'] = YEAR
        df['Season'] = SEASON
    
    
        if output is None:
            output = df.copy()
        else:
            output = pd.concat([output, df])

    return output

# %%
df_ids = CompileCSV('../Scraping/Season')
df_ids['MAL_id'] = df_ids.Link.str.extract(r'myanimelist.net/anime/(\d+)').astype(int)
df_ids.head()
# Out:
#                             Title  \
# 0            Shinseiki Evangelion
# 1              Gokinjo Monogatari
# 2               Bakuretsu Hunters
# 3               Kaitou Saint Tail
# 4  Shinpi no Sekai El-Hazard (TV)
#
#                                                 Link  Year Season  MAL_id
# 0  https://myanimelist.net/anime/30/Shinseiki_Eva...  1995   fall      30
# 1  https://myanimelist.net/anime/852/Gokinjo_Mono...  1995   fall     852
# 2  https://myanimelist.net/anime/495/Bakuretsu_Hu...  1995   fall     495
# 3  https://myanimelist.net/anime/1567/Kaitou_Sain...  1995   fall    1567
# 4  https://myanimelist.net/anime/116/Shinpi_no_Se...  1995   fall     116

# %%
df = CompileCSV('../Scraping/Detail/')
df_ids = df_ids.drop_duplicates('MAL_id')
df = pd.merge(df, df_ids[['Title', 'MAL_id']], on='Title', how='left')
df = df.set_index('MAL_id')

df = df.drop(columns=['Synonyms', 'Japanese', 'English', 'German', 'Spanish', 'French', 'Aired','Broadcast','Premiered'])
df.head(3).T
# Out:
# MAL_id                                                       14719  \
# Type                                                        ['TV']
# Episodes                                                        26
# Status                                             Finished Airing
# Producers        ['Yomiko Advertising', 'Warner Bros. Japan', '...
# Licensors                   ['VIZ Media', 'Warner Bros. Pictures']
# Studios                                       ['David Production']
# Source                                                   ['Manga']
# Genres                     ['Action', 'Adventure', 'Supernatural']
# Themes                                   ['Historical', 'Vampire']
# Demographic                                            ['Shounen']
# Duration                                           24 min. per ep.
# Rating                              R - 17+ (violence & profanity)
# Score                                                         7.87
# Ranked                                                        #877
# Popularity                                                     #58
# Members                                                  1,743,029
# Favorites                                                   38,219
# Scorers                                                  1124257.0
# Synopsis         The year is 1868; English nobleman George Joes...
# Related_Entries  ['Sequel (TV) JoJo no Kimyou na Bouken Part 3:...
# Title                                JoJo no Kimyou na Bouken (TV)
# Theme                                                          NaN
# Genre                                                          NaN
# Demographics                                                   NaN
# Year                                                          2012
# Season                                                        fall
#
# MAL_id                                                       13601  \
# Type                                                        ['TV']
# Episodes                                                        22
# Status                                             Finished Airing
# Producers        ['Dentsu', 'Fuji TV', 'Nitroplus', 'Sony Music...
# Licensors                                           ['Funimation']
# Studios                                         ['Production I.G']
# Source                                                    Original
# Genres                 ['Action', 'Mystery', 'Sci-Fi', 'Suspense']
# Themes                ['Adult Cast', 'Detective', 'Psychological']
# Demographic                                                    NaN
# Duration                                           23 min. per ep.
# Rating                              R - 17+ (violence & profanity)
# Score                                                         8.33
# Ranked                                                        #254
# Popularity                                                     #64
# Members                                                  1,686,077
# Favorites                                                   39,514
# Scorers                                                   806240.0
# Synopsis         Justice, and the enforcement of it, has change...
# Related_Entries  ['Sequel (TV) Psycho-Pass 2', 'Adaptation (Man...
# Title                                                  Psycho-Pass
# Theme                                                          NaN
# Genre                                                          NaN
# Demographics                                                   NaN
# Year                                                          2012
# Season                                                        fall
#
# MAL_id                                                       14741
# Type                                                        ['TV']
# Episodes                                                        12
# Status                                             Finished Airing
# Producers        ['Lantis', 'Pony Canyon', 'TBS', 'Rakuonsha', ...
# Licensors                                     ['Sentai Filmworks']
# Studios                                        ['Kyoto Animation']
# Source                                             ['Light novel']
# Genres                                       ['Comedy', 'Romance']
# Themes                                                         NaN
# Demographic                                                    NaN
# Duration                                           24 min. per ep.
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         7.70
# Ranked                                                       #1290
# Popularity                                                    #101
# Members                                                  1,404,581
# Favorites                                                   18,346
# Scorers                                                   802874.0
# Synopsis         Everybody has had that stage in their life whe...
# Related_Entries  ['Sequel (Special) Chuunibyou demo Koi ga Shit...
# Title                               Chuunibyou demo Koi ga Shitai!
# Theme                                                   ['School']
# Genre                                                          NaN
# Demographics                                                   NaN
# Year                                                          2012
# Season                                                        fall

# %%
def ExtractList(col : str):
    df[col] = df[col].str.findall(r"'([^']*)'")

for c in ['Producers', 'Licensors', 'Studios', 'Themes', 'Theme', 'Genres', 'Genre', 'Demographics', 'Demographic']:
    ExtractList(c)

# %%
def ExtractFirstItemInList(col : str):
    df[col] = df[col].str.extract(r"'([^']*)'")
    
for c in ['Source', 'Type']:
    ExtractFirstItemInList(c)

# %%
df['Episodes'] = df['Episodes'].replace('Unknown', np.nan).astype(float)

# %%
df['Is_Finished'] = df.Status == 'Finished Airing'
df = df.drop(columns=['Status'])

# %%
ExtractList('Related_Entries')
df['Related_Entries'] = df['Related_Entries'].apply(lambda x : len(x))

# %%
df['Synopsis'] = df['Synopsis'].str.replace(r'\[.*Written.*?\]|\(.*Source.*?\)|^No synopsis information has been added to this title. Help improve our database by adding a synopsis here.', '', regex=True)

# %%
df['Year'] = df['Year'].astype(int)
df['Members'] = df['Members'].replace(',','', regex=True).astype(int)
df['Favorites'] = df['Favorites'].replace(',','', regex=True).astype(int)

# %%
df['Score'] = df['Score'].replace('[]', np.nan).astype(float)

# %%
df['Scorers'] = df['Scorers'].replace(np.nan, 0).astype(int)

# %%
df['Ranked'] = df['Ranked'].replace('#', '', regex=True).astype(float)
df['Popularity'] = df['Popularity'].replace('#', '', regex=True).astype(int)

# %%
df['Themes'] = df['Theme'].combine_first(df['Themes'])
df['Genres'] = df['Genre'].combine_first(df['Genres'])
df['Demographics'] = df['Demographic'].combine_first(df['Demographics'])
df = df.drop(columns=['Theme', 'Genre', 'Demographic'])

# %%
def ExtractMinutes(time_str : str):
    hours_match = re.search(r'(\d+)\s*hr', time_str)
    minutes_match = re.search(r'(\d+)\s*min', time_str)

    minutes = 0
    if hours_match:
        minutes += int(hours_match.group(1)) * 60
    if minutes_match:
        minutes += int(minutes_match.group(1)) 

    return minutes

df['Duration'] = df['Duration'].apply(lambda x: ExtractMinutes(str(x)))

# %%
df.head().T
# Out:
# MAL_id                                                       14719  \
# Type                                                            TV
# Episodes                                                      26.0
# Producers        [Yomiko Advertising, Warner Bros. Japan, Klock...
# Licensors                       [VIZ Media, Warner Bros. Pictures]
# Studios                                         [David Production]
# Source                                                       Manga
# Genres                           [Action, Adventure, Supernatural]
# Themes                                       [Historical, Vampire]
# Duration                                                        24
# Rating                              R - 17+ (violence & profanity)
# Score                                                         7.87
# Ranked                                                       877.0
# Popularity                                                      58
# Members                                                    1743029
# Favorites                                                    38219
# Scorers                                                    1124257
# Synopsis         The year is 1868; English nobleman George Joes...
# Related_Entries                                                  4
# Title                                JoJo no Kimyou na Bouken (TV)
# Demographics                                             [Shounen]
# Year                                                          2012
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                       13601  \
# Type                                                            TV
# Episodes                                                      22.0
# Producers        [Dentsu, Fuji TV, Nitroplus, Sony Music Entert...
# Licensors                                             [Funimation]
# Studios                                           [Production I.G]
# Source                                                         NaN
# Genres                         [Action, Mystery, Sci-Fi, Suspense]
# Themes                      [Adult Cast, Detective, Psychological]
# Duration                                                        23
# Rating                              R - 17+ (violence & profanity)
# Score                                                         8.33
# Ranked                                                       254.0
# Popularity                                                      64
# Members                                                    1686077
# Favorites                                                    39514
# Scorers                                                     806240
# Synopsis         Justice, and the enforcement of it, has change...
# Related_Entries                                                  2
# Title                                                  Psycho-Pass
# Demographics                                                   NaN
# Year                                                          2012
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                       14741  \
# Type                                                            TV
# Episodes                                                      12.0
# Producers        [Lantis, Pony Canyon, TBS, Rakuonsha, Animatio...
# Licensors                                       [Sentai Filmworks]
# Studios                                          [Kyoto Animation]
# Source                                                 Light novel
# Genres                                           [Comedy, Romance]
# Themes                                                    [School]
# Duration                                                        24
# Rating                                   PG-13 - Teens 13 or older
# Score                                                          7.7
# Ranked                                                      1290.0
# Popularity                                                     101
# Members                                                    1404581
# Favorites                                                    18346
# Scorers                                                     802874
# Synopsis         Everybody has had that stage in their life whe...
# Related_Entries                                                  2
# Title                               Chuunibyou demo Koi ga Shitai!
# Demographics                                                   NaN
# Year                                                          2012
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                       13759  \
# Type                                                            TV
# Episodes                                                      24.0
# Producers        [Frontier Works, Genco, Media Factory, Animax,...
# Licensors                                       [Sentai Filmworks]
# Studios                                                [J.C.Staff]
# Source                                                 Light novel
# Genres                                            [Drama, Romance]
# Themes                                       [School, Visual Arts]
# Duration                                                        23
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         8.05
# Ranked                                                       602.0
# Popularity                                                     110
# Members                                                    1282772
# Favorites                                                    26217
# Scorers                                                     725493
# Synopsis         At Suimei High, the Sakura-sou dormitory is in...
# Related_Entries                                                  2
# Title                                  Sakura-sou no Pet na Kanojo
# Demographics                                                   NaN
# Year                                                          2012
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                       14227
# Type                                                            TV
# Episodes                                                      13.0
# Producers          [TV Tokyo, Aniplex, Nihon Ad Systems, Kodansha]
# Licensors                                      [NIS America, Inc.]
# Studios                                                         []
# Source                                                       Manga
# Genres                                           [Comedy, Romance]
# Themes                                                    [School]
# Duration                                                        24
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         7.46
# Ranked                                                      2096.0
# Popularity                                                     139
# Members                                                    1123389
# Favorites                                                     6485
# Scorers                                                     627564
# Synopsis         Shizuku Mizutani is apathetic toward her class...
# Related_Entries                                                  2
# Title                                       Tonari no Kaibutsu-kun
# Demographics                                              [Shoujo]
# Year                                                          2012
# Season                                                        fall
# Is_Finished                                                   True

# %%
df.dtypes
# Out:
# Type                object
# Episodes           float64
# Producers           object
# Licensors           object
# Studios             object
# Source              object
# Genres              object
# Themes              object
# Duration             int64
# Rating              object
# Score              float64
# Ranked             float64
# Popularity           int64
# Members              int64
# Favorites            int64
# Scorers              int64
# Synopsis            object
# Related_Entries      int64
# Title               object
# Demographics        object
# Year                 int64
# Season              object
# Is_Finished           bool
# dtype: object

# %%
df.to_csv('Cleaned.csv')

# %% [markdown]
# # Utility Matrix

# %%
def OneHotList(input_df, col, prefix):
    output = input_df[[col]]

    output = output.fillna('FILLNA')
    
    for i in output[col].explode().unique():
        output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)

    if f'{prefix}FILLNA' in output.columns:
        output = output.drop(columns=[f'{prefix}FILLNA'])

    output = output.drop(columns=[col])
    return output

# %%
USM = df[['Title', 'Is_Finished']].copy()
USM['Is_Finished'] = USM['Is_Finished'].astype(np.int8)

items = [('Genres', 'Genre_'),
         ('Demographics', 'Demo_'),
         ('Themes', 'Theme_'),
         ('Studios', 'Studio_'),
         ('Producers', 'Producer_'),
         ('Licensors', 'Licensor_'),
        ]

for i in items:      
    USM = pd.concat(axis=1, objs= [USM, OneHotList(df, i[0], i[1])])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# ...
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23360\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)

# %%
df.loc[40776]
# Out:
# Type                                                              TV
# Episodes                                                        12.0
# Producers          [Dentsu, Mainichi Broadcasting System, Movic, ...
# Licensors                                         [Sentai Filmworks]
# Studios                                             [Production I.G]
# Source                                                         Manga
# Genres                                                      [Sports]
# Themes                                         [School, Team Sports]
# Duration                                                          23
# Rating                                     PG-13 - Teens 13 or older
# Score                                                           8.55
# Ranked                                                         124.0
# Popularity                                                       219
# Members                                                       863774
# Favorites                                                       6318
# Scorers                                                       513859
# Synopsis           Once called a fallen powerhouse and known as "...
# Related_Entries                                                    4
# Title                                    Haikyuu!! To the Top Part 2
# Demographics                                               [Shounen]
# Year                                                            2020
# Season                                                          fall
# Is_Finished                                                     True
# Name: 40776, dtype: object

# %%
items = [
    ['Type', 'Type'],
    ['Rating', 'Rating'],
    ['Source', 'Source'],
]

for i in items:      
    USM = pd.concat(axis=1, objs= [USM, 
                                   pd.get_dummies(df[i[0]], prefix=i[1]).astype(np.int8)])

# %%
USM = pd.concat([USM, df[['Score', 'Members', 'Favorites', 'Related_Entries', 'Year', 'Episodes']]], axis=1)

# %%
USM
# Out:
#                                                     Title  Is_Finished  \
# MAL_id
# 14719                       JoJo no Kimyou na Bouken (TV)            1
# 13601                                         Psycho-Pass            1
# 14741                      Chuunibyou demo Koi ga Shitai!            1
# 13759                         Sakura-sou no Pet na Kanojo            1
# 14227                              Tonari no Kaibutsu-kun            1
# ...                                                   ...          ...
# 58606         Girls & Panzer: Saishuushou Part 4 Specials            1
# 58006   Science SARU x MBS Original Short Anime Daisak...            1
# 58229                            Harutsugeuo to Fuuraibou            1
# 58605                           Moja to Majo (TV Special)            1
# 58308                         Hakofugu to Minamata no Umi            1
#
#         Genre_Action  Genre_Adventure  Genre_Supernatural  Genre_Mystery  \
# MAL_id
# 14719              1                1                   1              0
# 13601              1                0                   0              1
# 14741              0                0                   0              0
# 13759              0                0                   0              0
# 14227              0                0                   0              0
# ...              ...              ...                 ...            ...
# 58606              0                0                   0              0
# 58006              0                0                   0              0
# 58229              0                1                   0              0
# 58605              0                0                   0              0
# 58308              0                1                   0              0
#
#         Genre_Sci-Fi  Genre_Suspense  Genre_Comedy  Genre_Romance  ...  \
# MAL_id                                                             ...
# 14719              0               0             0              0  ...
# 13601              1               1             0              0  ...
# 14741              0               0             1              1  ...
# 13759              0               0             0              1  ...
# 14227              0               0             1              1  ...
# ...              ...             ...           ...            ...  ...
# 58606              0               0             1              0  ...
# 58006              0               0             0              0  ...
# 58229              0               0             0              0  ...
# 58605              0               0             0              0  ...
# 58308              0               0             0              0  ...
#
#         Source_4-koma manga  Source_Light novel  Source_Manga  \
# MAL_id
# 14719                     0                   0             1
# 13601                     0                   0             0
# 14741                     0                   1             0
# 13759                     0                   1             0
# 14227                     0                   0             1
# ...                     ...                 ...           ...
# 58606                     0                   0             0
# 58006                     0                   0             0
# 58229                     0                   0             0
# 58605                     0                   0             0
# 58308                     0                   0             0
#
#         Source_Web manga  Score  Members  Favorites  Related_Entries  Year  \
# MAL_id
# 14719                  0   7.87  1743029      38219                4  2012
# 13601                  0   8.33  1686077      39514                2  2012
# 14741                  0   7.70  1404581      18346                2  2012
# 13759                  0   8.05  1282772      26217                2  2012
# 14227                  0   7.46  1123389       6485                2  2012
# ...                  ...    ...      ...        ...              ...   ...
# 58606                  0   7.29     2956          2                0  2024
# 58006                  0   6.06      538          0                0  2024
# 58229                  0    NaN      232          0                0  2024
# 58605                  0    NaN      113          0                0  2024
# 58308                  0    NaN      105          0                0  2024
#
#         Episodes
# MAL_id
# 14719       26.0
# 13601       22.0
# 14741       12.0
# 13759       24.0
# 14227       13.0
# ...          ...
# 58606        2.0
# 58006        4.0
# 58229        1.0
# 58605        1.0
# 58308        1.0
#
# [13928 rows x 2112 columns]

# %%
USM.to_csv('USM.csv')
