# %%
import pandas as pd
import numpy as np
from os import listdir
import re

# %% [markdown]
# # Parsing

# %%
def CompileCSV(FOLDER : str):
    FILENAMES = [f'{FOLDER}/{file}' for file in listdir(FOLDER)[1:]]
    FILENAMES
    
    output = None
    
    for f in FILENAMES:
        if f[-4:] != '.csv':
            break
    
        df = None
    
        YEAR, SEASON = f.split('/')[-1].strip('.csv').split('_')
        #print(YEAR, SEASON)
    
        df = pd.read_csv(f).drop(columns='Unnamed: 0')
        df['Year'] = YEAR
        df['Season'] = SEASON
    
    
        if output is None:
            output = df.copy()
        else:
            output = pd.concat([output, df])

    return output

# %%
df_ids = CompileCSV('../Scraping/Season')
df_ids['MAL_id'] = df_ids.Link.str.extract(r'myanimelist.net/anime/(\d+)').astype(int)
df_ids.head()
# Out:
#                             Title  \
# 0            Shinseiki Evangelion
# 1              Gokinjo Monogatari
# 2               Bakuretsu Hunters
# 3               Kaitou Saint Tail
# 4  Shinpi no Sekai El-Hazard (TV)
#
#                                                 Link  Year Season  MAL_id
# 0  https://myanimelist.net/anime/30/Shinseiki_Eva...  1995   fall      30
# 1  https://myanimelist.net/anime/852/Gokinjo_Mono...  1995   fall     852
# 2  https://myanimelist.net/anime/495/Bakuretsu_Hu...  1995   fall     495
# 3  https://myanimelist.net/anime/1567/Kaitou_Sain...  1995   fall    1567
# 4  https://myanimelist.net/anime/116/Shinpi_no_Se...  1995   fall     116

# %%
df = CompileCSV('../Scraping/Detail/')
df_ids = df_ids.drop_duplicates('MAL_id')
df = pd.merge(df, df_ids[['Title', 'MAL_id']], on='Title', how='left')
df = df.set_index('MAL_id')

df = df.drop(columns=['Synonyms', 'Japanese', 'English', 'German', 'Spanish', 'French', 'Aired', 'Synopsis','Broadcast','Premiered'])
df.head(3).T
# Out:
# MAL_id                                                       40748  \
# Type                                                        ['TV']
# Episodes                                                        24
# Status                                             Finished Airing
# Producers        ['Mainichi Broadcasting System', 'TOHO animati...
# Licensors                                            ['VIZ Media']
# Studios                                                  ['MAPPA']
# Source                                                   ['Manga']
# Genres                 ['Action', 'Award Winning', 'Supernatural']
# Theme                                                   ['School']
# Demographic                                            ['Shounen']
# Duration                                           23 min. per ep.
# Rating                              R - 17+ (violence & profanity)
# Score                                                         8.57
# Ranked                                                        #109
# Popularity                                                     #13
# Members                                                  2,740,023
# Favorites                                                   93,063
# Scorers                                                  1798795.0
# Related_Entries  ['Prequel (Movie) Jujutsu Kaisen 0 Movie', 'Se...
# Title                                               Jujutsu Kaisen
# Genre                                                          NaN
# Themes                                                         NaN
# Demographics                                                   NaN
# Year                                                          2020
# Season                                                        fall
#
# MAL_id                                                       40776  \
# Type                                                        ['TV']
# Episodes                                                        12
# Status                                             Finished Airing
# Producers        ['Dentsu', 'Mainichi Broadcasting System', 'Mo...
# Licensors                                     ['Sentai Filmworks']
# Studios                                         ['Production I.G']
# Source                                                   ['Manga']
# Genres                                                         NaN
# Theme                                                          NaN
# Demographic                                            ['Shounen']
# Duration                                           23 min. per ep.
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         8.55
# Ranked                                                        #124
# Popularity                                                    #219
# Members                                                    863,774
# Favorites                                                    6,318
# Scorers                                                   513859.0
# Related_Entries  ['Prequel (TV) Haikyuu!! To the Top', 'Sequel ...
# Title                                  Haikyuu!! To the Top Part 2
# Genre                                                   ['Sports']
# Themes                                   ['School', 'Team Sports']
# Demographics                                                   NaN
# Year                                                          2020
# Season                                                        fall
#
# MAL_id                                                       41389
# Type                                                        ['TV']
# Episodes                                                        12
# Status                                             Finished Airing
# Producers        ['Shogakukan-Shueisha Productions', 'Warner Br...
# Licensors                                        ['Anime Limited']
# Studios                                             ['Seven Arcs']
# Source                                                   ['Manga']
# Genres                                       ['Comedy', 'Romance']
# Theme                                                          NaN
# Demographic                                            ['Shounen']
# Duration                                           23 min. per ep.
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         7.86
# Ranked                                                        #912
# Popularity                                                    #264
# Members                                                    783,366
# Favorites                                                   10,209
# Scorers                                                   440794.0
# Related_Entries  ['Sequel (OVA) Tonikaku Kawaii: SNS', 'Adaptat...
# Title                                              Tonikaku Kawaii
# Genre                                                          NaN
# Themes                                                         NaN
# Demographics                                                   NaN
# Year                                                          2020
# Season                                                        fall

# %%
def ExtractList(col : str):
    df[col] = df[col].str.findall(r"'([^']*)'")

for c in ['Producers', 'Licensors', 'Studios', 'Themes', 'Theme', 'Genres', 'Genre', 'Demographics', 'Demographic']:
    ExtractList(c)

# %%
def ExtractFirstItemInList(col : str):
    df[col] = df[col].str.extract(r"'([^']*)'")
    
for c in ['Source', 'Type']:
    ExtractFirstItemInList(c)

# %%
df['Episodes'] = df['Episodes'].replace('Unknown', np.nan).astype(float)

# %%
df['Is_Finished'] = df.Status == 'Finished Airing'
df = df.drop(columns=['Status'])

# %%
ExtractList('Related_Entries')
df['Related_Entries'] = df['Related_Entries'].apply(lambda x : len(x))

# %%
df['Year'] = df['Year'].astype(int)
df['Members'] = df['Members'].replace(',','', regex=True).astype(int)
df['Favorites'] = df['Favorites'].replace(',','', regex=True).astype(int)

# %%
df['Score'] = df['Score'].replace('[]', np.nan).astype(float)

# %%
df['Scorers'] = df['Scorers'].replace(np.nan, 0).astype(int)

# %%
df['Ranked'] = df['Ranked'].replace('#', '', regex=True).astype(float)
df['Popularity'] = df['Popularity'].replace('#', '', regex=True).astype(int)

# %%
df['Themes'] = df['Theme'].combine_first(df['Themes'])
df['Genres'] = df['Genre'].combine_first(df['Genres'])
df['Demographics'] = df['Demographic'].combine_first(df['Demographics'])
df = df.drop(columns=['Theme', 'Genre', 'Demographic'])

# %%
def ExtractMinutes(time_str : str):
    hours_match = re.search(r'(\d+)\s*hr', time_str)
    minutes_match = re.search(r'(\d+)\s*min', time_str)

    minutes = 0
    if hours_match:
        minutes += int(hours_match.group(1)) * 60
    if minutes_match:
        minutes += int(minutes_match.group(1)) 

    return minutes

df['Duration'] = df['Duration'].apply(lambda x: ExtractMinutes(str(x)))

# %%
df.head().T
# Out:
# MAL_id                                                       40748  \
# Type                                                            TV
# Episodes                                                      24.0
# Producers        [Mainichi Broadcasting System, TOHO animation,...
# Licensors                                              [VIZ Media]
# Studios                                                    [MAPPA]
# Source                                                       Manga
# Genres                       [Action, Award Winning, Supernatural]
# Duration                                                        23
# Rating                              R - 17+ (violence & profanity)
# Score                                                         8.57
# Ranked                                                       109.0
# Popularity                                                      13
# Members                                                    2740023
# Favorites                                                    93063
# Scorers                                                    1798795
# Related_Entries                                                  4
# Title                                               Jujutsu Kaisen
# Themes                                                    [School]
# Demographics                                             [Shounen]
# Year                                                          2020
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                       40776  \
# Type                                                            TV
# Episodes                                                      12.0
# Producers        [Dentsu, Mainichi Broadcasting System, Movic, ...
# Licensors                                       [Sentai Filmworks]
# Studios                                           [Production I.G]
# Source                                                       Manga
# Genres                                                    [Sports]
# Duration                                                        23
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         8.55
# Ranked                                                       124.0
# Popularity                                                     219
# Members                                                     863774
# Favorites                                                     6318
# Scorers                                                     513859
# Related_Entries                                                  4
# Title                                  Haikyuu!! To the Top Part 2
# Themes                                       [School, Team Sports]
# Demographics                                             [Shounen]
# Year                                                          2020
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                       41389  \
# Type                                                            TV
# Episodes                                                      12.0
# Producers        [Shogakukan-Shueisha Productions, Warner Bros....
# Licensors                                          [Anime Limited]
# Studios                                               [Seven Arcs]
# Source                                                       Manga
# Genres                                           [Comedy, Romance]
# Duration                                                        23
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         7.86
# Ranked                                                       912.0
# Popularity                                                     264
# Members                                                     783366
# Favorites                                                    10209
# Scorers                                                     440794
# Related_Entries                                                  2
# Title                                              Tonikaku Kawaii
# Themes                                                         NaN
# Demographics                                             [Shounen]
# Year                                                          2020
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                       40454  \
# Type                                                            TV
# Episodes                                                      12.0
# Producers        [Movic, Warner Bros. Japan, KlockWorx, Hakuhod...
# Licensors                                       [Sentai Filmworks]
# Studios                                                [J.C.Staff]
# Source                                                 Light novel
# Genres                                [Action, Adventure, Fantasy]
# Duration                                                        23
# Rating                                   PG-13 - Teens 13 or older
# Score                                                         7.46
# Ranked                                                      2105.0
# Popularity                                                     357
# Members                                                     638294
# Favorites                                                     1933
# Scorers                                                     332460
# Related_Entries                                                  4
# Title            Dungeon ni Deai wo Motomeru no wa Machigatteir...
# Themes                                                         NaN
# Demographics                                                   NaN
# Year                                                          2020
# Season                                                        fall
# Is_Finished                                                   True
#
# MAL_id                                                       41433
# Type                                                            TV
# Episodes                                                      12.0
# Producers        [Marvelous Entertainment, Yomiko Advertising, ...
# Licensors                                             [Funimation]
# Studios                                                  [Pierrot]
# Source                                                         NaN
# Genres                                  [Action, Sci-Fi, Suspense]
# Duration                                                        24
# Rating                              R - 17+ (violence & profanity)
# Score                                                         7.58
# Ranked                                                      1637.0
# Popularity                                                     523
# Members                                                     458195
# Favorites                                                     3875
# Scorers                                                     212570
# Related_Entries                                                  0
# Title                                                Akudama Drive
# Themes                                          [Adult Cast, Gore]
# Demographics                                                   NaN
# Year                                                          2020
# Season                                                        fall
# Is_Finished                                                   True

# %%
df.dtypes
# Out:
# Type                object
# Episodes           float64
# Producers           object
# Licensors           object
# Studios             object
# Source              object
# Genres              object
# Duration             int64
# Rating              object
# Score              float64
# Ranked             float64
# Popularity           int64
# Members              int64
# Favorites            int64
# Scorers              int64
# Related_Entries      int64
# Title               object
# Themes              object
# Demographics        object
# Year                 int64
# Season              object
# Is_Finished           bool
# dtype: object

# %%
df.to_csv('Cleaned.csv')

# %% [markdown]
# # Utility Matrix

# %%
def OneHotList(input_df, col, prefix):
    output = input_df[[col]]

    output = output.fillna('FILLNA')
    
    for i in output[col].explode().unique():
        output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)

    if f'{prefix}FILLNA' in output.columns:
        output = output.drop(columns=[f'{prefix}FILLNA'])

    output = output.drop(columns=[col])
    return output

# %%
USM = df[['Title', 'Is_Finished']].copy()
USM['Is_Finished'] = USM['Is_Finished'].astype(np.int8)

items = [('Genres', 'Genre_'),
         ('Demographics', 'Demo_'),
         ('Themes', 'Theme_'),
         ('Studios', 'Studio_'),
         ('Producers', 'Producer_'),
         ('Licensors', 'Licensor_'),
        ]

for i in items:      
    USM = pd.concat(axis=1, objs= [USM, OneHotList(df, i[0], i[1])])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# ...
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18804\2727251450.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   output[f'{prefix}{i}'] = output[col].apply(lambda x: 1 if i in x else 0)

# %%
df.reset_index()[df.reset_index().MAL_id == 40776]
# Out:
#    MAL_id Type  Episodes                                          Producers  \
# 1   40776   TV      12.0  [Dentsu, Mainichi Broadcasting System, Movic, ...
#
#             Licensors           Studios Source    Genres  Duration  \
# 1  [Sentai Filmworks]  [Production I.G]  Manga  [Sports]        23
#
#                       Rating  ...  Members  Favorites  Scorers  \
# 1  PG-13 - Teens 13 or older  ...   863774       6318   513859
#
#    Related_Entries                        Title                 Themes  \
# 1                4  Haikyuu!! To the Top Part 2  [School, Team Sports]
#
#    Demographics  Year Season Is_Finished
# 1     [Shounen]  2020   fall        True
#
# [1 rows x 23 columns]

# %%
items = [
    ['Type', 'Type'],
    ['Rating', 'Rating'],
    ['Source', 'Source'],
]

for i in items:      
    USM = pd.concat(axis=1, objs= [USM, 
                                   pd.get_dummies(df[i[0]], prefix=i[1]).astype(np.int8)])

# %%
USM
# Out:
#                                                     Title  Is_Finished  \
# MAL_id
# 40748                                      Jujutsu Kaisen            1
# 40776                         Haikyuu!! To the Top Part 2            1
# 41389                                     Tonikaku Kawaii            1
# 40454   Dungeon ni Deai wo Motomeru no wa Machigatteir...            1
# 41433                                       Akudama Drive            1
# ...                                                   ...          ...
# 58606         Girls & Panzer: Saishuushou Part 4 Specials            1
# 58006   Science SARU x MBS Original Short Anime Daisak...            1
# 58229                            Harutsugeuo to Fuuraibou            1
# 58605                           Moja to Majo (TV Special)            1
# 58308                         Hakofugu to Minamata no Umi            1
#
#         Genre_Action  Genre_Award Winning  Genre_Supernatural  Genre_Sports  \
# MAL_id
# 40748              1                    1                   1             0
# 40776              0                    0                   0             1
# 41389              0                    0                   0             0
# 40454              1                    0                   0             0
# 41433              1                    0                   0             0
# ...              ...                  ...                 ...           ...
# 58606              0                    0                   0             0
# 58006              0                    0                   0             0
# 58229              0                    0                   0             0
# 58605              0                    0                   0             0
# 58308              0                    0                   0             0
#
#         Genre_Comedy  Genre_Romance  Genre_Adventure  Genre_Fantasy  ...  \
# MAL_id                                                               ...
# 40748              0              0                0              0  ...
# 40776              0              0                0              0  ...
# 41389              1              1                0              0  ...
# 40454              0              0                1              1  ...
# 41433              0              0                0              0  ...
# ...              ...            ...              ...            ...  ...
# 58606              1              0                0              0  ...
# 58006              0              0                0              0  ...
# 58229              0              0                1              0  ...
# 58605              0              0                0              1  ...
# 58308              0              0                1              1  ...
#
#         Rating_G - All Ages  Rating_PG - Children  \
# MAL_id
# 40748                     0                     0
# 40776                     0                     0
# 41389                     0                     0
# 40454                     0                     0
# 41433                     0                     0
# ...                     ...                   ...
# 58606                     0                     0
# 58006                     0                     0
# 58229                     1                     0
# 58605                     1                     0
# 58308                     1                     0
#
#         Rating_PG-13 - Teens 13 or older  \
# MAL_id
# 40748                                  0
# 40776                                  1
# 41389                                  1
# 40454                                  1
# 41433                                  0
# ...                                  ...
# 58606                                  1
# 58006                                  1
# 58229                                  0
# 58605                                  0
# 58308                                  0
#
#         Rating_R - 17+ (violence & profanity)  Rating_R+ - Mild Nudity  \
# MAL_id
# 40748                                       1                        0
# 40776                                       0                        0
# 41389                                       0                        0
# 40454                                       0                        0
# 41433                                       1                        0
# ...                                       ...                      ...
# 58606                                       0                        0
# 58006                                       0                        0
# 58229                                       0                        0
# 58605                                       0                        0
# 58308                                       0                        0
#
#         Rating_Rx - Hentai  Source_4-koma manga  Source_Light novel  \
# MAL_id
# 40748                    0                    0                   0
# 40776                    0                    0                   0
# 41389                    0                    0                   0
# 40454                    0                    0                   1
# 41433                    0                    0                   0
# ...                    ...                  ...                 ...
# 58606                    0                    0                   0
# 58006                    0                    0                   0
# 58229                    0                    0                   0
# 58605                    0                    0                   0
# 58308                    0                    0                   0
#
#         Source_Manga  Source_Web manga
# MAL_id
# 40748              1                 0
# 40776              1                 0
# 41389              1                 0
# 40454              0                 0
# 41433              0                 0
# ...              ...               ...
# 58606              0                 0
# 58006              0                 0
# 58229              0                 0
# 58605              0                 0
# 58308              0                 0
#
# [4897 rows x 1425 columns]

# %%
USM.to_csv('USM.csv')
