# %%
from src import *

import numpy as np
import pandas as pd

from typing import List

# %% [markdown]
# # READ
# > Don't try to actually run all cells. It would take too long from the delay added <br>
# > Just choose which segments require testing.
# >
# > Reduce `MINIMUM_DELAY` at your own risk of being blocked
#
# > To perform scraping of `Details`, `StatisticsSummary`, `StatisticsSubmissions`, ensure there's a `csv` already in `Season/`.<br>
# > Otherwise run `AutomateSeason()` in the `Seasons` segment to generate the database of anime links.

# %%
Scraper.MINIMUM_DELAY = 10

# %% [markdown]
# # Seasons

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
def AutomateSeason(YEARS : List[str]):
    for YEAR in YEARS:
        for SEASON in Scraper.SEASONS.__members__.values():
            url = Scraper.build_URL_Seasons(YEAR, SEASON)
            print(url)
    
            try:
                seasonalSoup = Scraper.scrape(url)
                df_Season = pd.DataFrame(SeasonPage.parse(seasonalSoup))
    
                filename = f'Season/{YEAR}_{SEASON.value}.csv'
                df_Season.to_csv(filename)
                print(filename)
    
            except Exception as e:
                print(url, e)

# %% [markdown]
# ## 1. Scrape All 1996 Seasons Record

# %%
AutomateSeason(np.arange(1995, 1996))

# %% [markdown]
# ## 2. Scrape Modern Anime (2020-2025)

# %%
AutomateSeason(np.arange(2020, 2026))

# %%
AutomateSeason(np.arange(1996, 2020))

# %% [markdown]
# # Details

# %%
assert False

# %% [markdown]
# ## 1. Scrape [First 2, 2 Random, and Last 2] Anime from 1995 Fall

# %%
SEASON = Scraper.SEASONS.FALL.value
YEAR = 1995

# %%
df = pd.read_csv(f'Season/{YEAR}_{SEASON}.csv', index_col=0)
df_Target = df.iloc[[0,1,
                np.random.randint(2,df.shape[0]-2),
                np.random.randint(2,df.shape[0]-2),
                -2,-1]].copy()

df_Target

# %%
df_Details = None

for _, row in df_Target.iterrows():
    output = {}
    newRow = None
    
    try:
        soup = Scraper.scrape(row.Link)
        output = DetailsPage.parse(soup)
        output['Title'] = row.Title

        newRow = pd.DataFrame([output])
        
        if df_Details is None:
            df_Details = newRow
        else:
            df_Details = pd.concat([df_Details, newRow], ignore_index=True)
        
        print(row.Title)
    except Exception as e:
        print(f'ERROR: {row.Link} {e}')

# %%
filename = f'Detail/{YEAR}_{SEASON}_sample.csv'
df_Details.to_csv(filename)

# %% [markdown]
# ## 2. Scrape All Entries From Specific Year and Season

# %%
def AutomateDetails(YEAR : int | str, SEASON : Scraper.SEASONS):
    df_Details = None

    for _, row in pd.read_csv(f'Season/{YEAR}_{SEASON.value}.csv').iterrows():
        output = {}
        newRow = None
        
        try:
            soup = Scraper.scrape(row.Link)
            output = DetailsPage.parse(soup)
            output['Title'] = row.Title
    
            newRow = pd.DataFrame([output])
            
            if df_Details is None:
                df_Details = newRow
            else:
                df_Details = pd.concat([df_Details, newRow], ignore_index=True)
            
            print(row.Title)
        except Exception as e:
            print(f'ERROR: {row.Link} {e}')    
        
    filename = f'Detail/{YEAR}_{SEASON.value}.csv'
    df_Details.to_csv(filename)
    print(filename)

# %%
AutomateDetails(2024, Scraper.SEASONS.FALL)

# %%
for YEAR in np.arange(2014, 2020):
    for SEASON in Scraper.SEASONS.__members__.values():
    #for SEASON in [Scraper.SEASONS.SPRING, Scraper.SEASONS.SUMMER, Scraper.SEASONS.WINTER]:
        print(YEAR, SEASON)
        AutomateDetails(YEAR, SEASON)
# Out:
# 2014 SEASONS.FALL
# Shigatsu wa Kimi no Uso
# Nanatsu no Taizai
# Kiseijuu: Sei no Kakuritsu
# Fate/stay night: Unlimited Blade Works
# Akatsuki no Yona
# Trinity Seven
# Amagi Brilliant Park
# Psycho-Pass 2
# Grisaia no Kajitsu
# Log Horizon 2nd Season
# Ookami Shoujo to Kuro Ouji
# Shirobako
# World Trigger
# Inou-Battle wa Nichijou-kei no Naka de
# Shingeki no Bahamut: Genesis
# Madan no Ou to Vanadis
# Danna ga Nani wo Itteiru ka Wakaranai Ken
# Mushishi Zoku Shou 2nd Season
# Terra Formars
# Cross Ange: Tenshi to Ryuu no Rondo
# Hitsugi no Chaika: Avenging Battle
# Gugure! Kokkuri-san
# Ore, Twintail ni Narimasu.
# Yuuki Yuuna wa Yuusha de Aru
# Garo: Honoo no Kokuin
# Yowamushi Pedal: Grande Road
# Daitoshokan no Hitsujikai
# Denki-gai no Honya-san
# Donten ni Warau
# Magic Kaito 1412
# Orenchi no Furo Jijou
# Sora no Method
# Ushinawareta Mirai wo Motomete
# Selector Spread WIXOSS
# Gundam Build Fighters Try
# Girlfriend (Kari)
# Ai Tenchi Muyou!
# Gundam: G no Reconguista
# Sanzoku no Musume Ronja
# Cardfight!! Vanguard G
# Kaitou Joker
# Hi☆sCoool! SeHa Girls
# Tribe Cool Crew
# Garo: Honoo no Kokuin - Yurugaro
# No score
# Score Failed
# Nano Invaders
# Konna Watashitachi ga Nariyuki de Heroine ni Natta Kekka www (TV)
# Oshiri Kajiri Mushi (TV) 3rd Season
# Zhen Gyi Hong Shi
# Huoli Shaonian Wang zhi Chuanqi Zaixian
# No score
# Score Failed
# Gra-P & Rodeo
# No score
# Score Failed
# Fuusen Inu Tinny
# Xiong Chumo: Chunri Dui Dui Peng
# No score
# Score Failed
# Ganbare! Lulu Lolo 2nd Season
# No score
# Score Failed
# Miniforce
# No score
# Score Failed
# Hello Cocomong 2
# No score
# Score Failed
# G Fighters
# No score
# Score Failed
# Fan Kai Zhe Yi Ye
# No score
# Score Failed
# Budai Xiao Heshang
# No score
# Score Failed
# Iyab! Space Jungle
# No score
# Score Failed
# Yingxiong Fengzicai
# No score
# Score Failed
# Biklonz 2nd Season
# Naruto: Shippuuden
# One Piece
# Akame ga Kill!
# Sword Art Online II
# Fairy Tail (2014)
# Meitantei Conan
# Diamond no Ace
# Dragon Ball Kai (2014)
# Pokemon XY
# Crayon Shin-chan
# Yu☆Gi☆Oh! Arc-V
# Aikatsu!
# Shirogane no Ishi: Argevollen
# Yama no Susume Second Season
# Youkai Watch
# PriPara
# Doraemon (2005)
# Gudetama
# Happiness Charge Precure!
# Lady Jewelpet
# Future Card Buddyfight
# Furusato Saisei: Nippon no Mukashibanashi
# Francesca
# Majin Bone
# Marvel Disk Wars: The Avengers
# Sazae-san
# Nintama Rantarou
# Chibi Maruko-chan (1995)
# Dragon Collection
# Tenkai Knights
# Sore Ike! Anpanman
# Ninja Hattori-kun (2012)
# Hero Bank
# Pac-World
# Oreca Battle
# Ojarumaru
# Duel Masters VS
# Maido! Urayasu Tekkin Kazoku
# No score
# Score Failed
# Kamiusagi Rope: Warau Asa ni wa Fukuraitaru tte Maji ssuka!?
# Larva 3rd Season
# Danchi Tomoo
# Hanakappa
# No score
# Score Failed
# Shiawase Haitatsu Taneko
# Xia Lan
# GO-GO Tamagotchi!
# No score
# Score Failed
# KutsuDaru.
# No score
# Score Failed
# Neko no Dayan
# Neko Pitcher
# No score
# Score Failed
# Shimajirou no Wow!
# Choubakuretsu Ijigen Menko Battle: Gigant Shooter Tsukasa
# Himitsukessha Taka no Tsume EX
# No score
# Score Failed
# Nyanfuru
# No score
# Score Failed
# Tetsujin 28-gou Gao!
# Annyeong Jadoo
# No score
# Score Failed
# Gohan Kaijuu Pap
# Chuldong! Super Wings
# Ohayou Hakushon Daimaou
# No score
# Score Failed
# Yowamushi Monsters
# No score
# Score Failed
# Ehon Yose
# No score
# Score Failed
# Panpaka Pants
# No score
# Score Failed
# Tomodachi 8-nin
# No score
# Score Failed
# Ganbare! Oden-kun
# No score
# Score Failed
# Astar-eul Hyanghae Chaguchagu
# No score
# Score Failed
# Yi Kong Zhi Dian
# No score
# Score Failed
# Norasco (TV)
# No score
# Score Failed
# Pakkororin
# No score
# Score Failed
# ColoColo Animal 2
# No score
# Score Failed
# Ppalgan Jajeongeo
# No score
# Score Failed
# Choegang Top Plate Part 2
# No score
# Score Failed
# Eungkka Sonata
# No score
# Score Failed
# Hello Carbot
# No score
# Score Failed
# Bubble Cook Wonjeongdae
# Bishoujo Senshi Sailor Moon Crystal
# Steins;Gate: Soumei Eichi no Cognitive Computing
# Bonjour♪Koiaji Pâtisserie
# AkaKill! Gekijou
# Nihon Animator Mihonichi
# Yaoguai Mingdan
# Madan no Ou to Vanadis: Tigre-kun to Vanadi-chu
# Pokemon Omega Ruby & Alpha Sapphire: Mega Special Animation
# Wake Up, Girl Zoo!
# Fastening Days
# Duan Nao
# Madan no Ou to Vanadis: Tigre-kun to Vanadi-chu Episode 0
# Shi Xiong
# Lu Shidai 2nd Season
# Monster High: Kowa-ike Girls
# Qin Shi Mingyue: Junlin Tianxia
# No score
# Score Failed
# Ar:pieL - 6-seosgae-ui Unmyeong
# Kujakuou: Sengoku Tensei
# Tensai Banpaku Opening
# Channel 5.5 4th Season
# Studio Khara vs. CyberConnect2 Gachinko! Animation Taiketsu!
# Mattsu to Yanma to Moburi-san 2: Suigun Otakara to Nazotoki no Shimajima
# Beppu x Peeping Life
# Channel 5.5 4th Season Prologue
# Nenga no Kizuna
# Curly
# Minion
# Oniku Daisuki! Zeushi-kun 2nd Season
# Kana Kana Kazoku: Rika in Wonderland
# Kana Kana Kazoku: Stop Rubella
# Windows Tablet no Uta
# Collapse Zen
# Kubbe no Ongakukai
# No score
# Score Failed
# Lion x Kamiusagi Rope
# No score
# Score Failed
# Tokyo 2164
# No score
# Score Failed
# Menghuan Xiyou
# No score
# Score Failed
# Sui Cheng Li Xin: Guiyu Zhou Yuan
# No score
# Score Failed
# AOKI & Taka no Tsume
# No score
# Score Failed
# Spookiz Specials
# No score
# Score Failed
# Spookiz
# No score
# Score Failed
# Tsubuyaki-tai × Otona no I
# No score
# Score Failed
# Hong Ling Jin Yu Wang Xiaoming
# No score
# Score Failed
# Chifan Shuijiao Da Dou Dou
# Shingeki no Kyojin: Kuinaki Sentaku
# Date A Live II: Kurumi Star Festival
# Nisekoi OVA
# Ao Haru Ride OVA
# Magi: Sinbad no Bouken
# To LOVE-Ru Darkness OVA
# Yamada-kun to 7-nin no Majo: Mou Hitotsu no Suzaku-sai
# Watashi ga Motenai no wa Dou Kangaetemo Omaera ga Warui!: Motenaishi, Nazomeite Miru
# IS: Infinite Stratos 2 - World Purge-hen
# Seitokai Yakuindomo* OVA
# Hybrid Child
# Love Stage!!: Chotto ja Nakutte
# Imawa no Kuni no Alice
# Ane Log: Moyako Neesan no Tomaranai Monologue
# Rance 01: Hikari wo Motomete The Animation
# Brothers Conflict OVA
# Strike Witches: Operation Victory Arrow
# Kanojo ga Flag wo Oraretara: Christmas? Sonna Mono ga Boku ni Tsuuyou Suru to Omou no ka?
# Kono Danshi, Sekka ni Nayandemasu.
# Boy Meets Harem The Animation
# Shin Tennis no Oujisama vs. Genius 10
# Diamond no Ace OVA
# Idol☆Sister
# Sei Brunehilde Gakuen Shoujo Kishidan to Junpaku no Panty The Animation
# Ikkitousen: Extravaganza Epoch
# 12-sai.
# Koi Maguwai
# Jutaijima
# Futari Ecchi (2014)
# Oppai Gakuen Marching Band-bu!
# Yakata: Kannou Kitan
# Ana no Oku no Ii Tokoro
# Shinkyoku no Grimoire The Animation
# Demonion: Gaiden
# Otome Hime
# Eromame
# Yobai Suru Shichinin no Harame
# Juuza Engi: Engetsu Sangokuden - Gaiden Youzhou Genya
# Oyome-sama Honey Days♥
# Jokei Kazoku III: Himitsu - The Anime
# Samurai Hormone The Animation
# Niku Mesu R30: Nikuyoku ni Ochita Mesu-tachi The Animation
# Kaitou Tenshi Twin Angel: Kyunkyun☆Tokimeki Paradise!! OVA
# Choujikuu Robo Meguru
# Elite Jack!!
# No score
# Score Failed
# Inui-san!
# No score
# Score Failed
# Mofu☆Mofu OVA
# No score
# Score Failed
# Onosaka Konishi no O+K 2.5-jigen Animation 2nd Season
# The Last: Naruto the Movie
# Shingeki no Kyojin Movie 1: Guren no Yumiya
# Rakuen Tsuihou
# Uchuu Senkan Yamato 2199: Hoshimeguru Hakobune
# Aikatsu! Movie
# Youkai Watch Movie 1: Tanjou no Himitsu da Nyan!
# Santa Company
# Happiness Charge Precure! Movie: Ningyou no Kuni no Ballerina
# Pikmin Short Movies
# Timing (Movie)
# Chiisana Teien
# No score
# Score Failed
# Kurumiwari Ningyou (2014)
# No score
# Score Failed
# Peeping Life Movie: We Are The Hero
# No score
# Score Failed
# Kushimitama Samurai
# No score
# Score Failed
# McDull: Wo He Wo Mama
# No score
# Score Failed
# Kiiroi Kikyu to Banno Sensei
# No score
# Score Failed
# 81 Hao Nongchang: Fengkuang de Mai Ji
# No score
# Score Failed
# Pororo Movie: Nun-yojeong Ma-eul Daemoheom
# No score
# Score Failed
# Shen Jian Chuanqi
# No score
# Score Failed
# Shi Er Shengxiao: Chengshi Yingxiong
# No score
# Score Failed
# Tao Wa Yuan Ji
# No score
# Score Failed
# Juroring Dongmultanjeong Geukjangpan
# Tsukimonogatari
# Fate/stay night: Unlimited Blade Works Prologue
# No Game No Life Specials
# Ansatsu Kyoushitsu: Deai no Jikan
# Sword Art Online II: Debriefing
# Grisaia no Kajitsu Specials
# Sword Art Online II: Sword Art Offline II
# Mangaka-san to Assistant-san to The Animation Specials
# Fate/kaleid liner Prisma☆Illya 2wei! Specials
# Amagi Brilliant Park: Wakuwaku Mini Theater - Rakugaki Backstage
# Tales of Zestiria: Doushi no Yoake
# Akuma no Riddle: Shousha wa Dare? Nukiuchi Test
# Seireitsukai no Blade Dance Specials
# DRAMAtical Murder: Data_xx_Transitory
# Pokemon XY: Mega Evolution
# Buddy Complex: Kanketsu-hen - Ano Sora ni Kaeru Mirai de
# Kuroko no Basket: Oshaberi Demo Shimasen ka
# Sekai Seifuku: Bouryaku no Zvezda - Shin Zvezda Daisakusen
# Black Bullet: Tenchuu＊Girls
# Sabage-bu! Specials
# Bokura wa Minna Kawai-sou Specials
# Ookami Shoujo to Kuro Ouji Recap
# Shingeki no Bahamut: Genesis - Roundup
# Gugure! Kokkuri-san Specials
# Persona 4 the Golden Animation: Thank you Mr. Accomplice
# Edogawa Conan Shissou Jiken: Shijou Saiaku no Futsukakan
# Yama no Susume Second Season Specials
# Tari Tari: Kumottari, Kagayaitari, Mata Itsuka Utattari
# Daitoshokan no Hitsujikai Picture Drama
# Isshuukan Friends. Tomodachi to no Omoide
# Ai Tenchi Muyou! Recaps
# Pokemon XY: New Year's Eve 2014 Super Mega Special
# Choboraunyopomi Gekijou Dai Ni Maku Ai Mai Mii: Mousou Catastrophe - Shojo Kuriya
# Space☆Dandy 2nd Season Picture Drama
# Go! Go! 575: Meippai ni, Hajiketeru?
# Houkago no Oujisama
# Uchuu Senkan Yamato 2199: Tsuioku no Koukai
# Zephyr
# Shin Strange+ Special
# Aikatsu!: Dai Starmiya Ichigo Matsuri Zenyasai!!
# Magic Knight Rayearth Pilot
# White Fantasy
# Mahou Shoujo Lyrical Nanoha A's Picture Drama
# Doraemon (2005) Specials
# Mahou Shoujo Lyrical Nanoha Picture Drama
# Kidou Senshi Gakuen: G-Reco Koushien
# Youkai Watch: Best 10
# Buggy Map
# Hamaneko
# Shukka Fuufu
# No score
# Score Failed
# Ken to Kaijuu
# No score
# Score Failed
# Norasco Specials
# No score
# Score Failed
# Sinbi Apartment 444ho
# No score
# Score Failed
# gdgd Fairies Movie Specials
# No score
# Score Failed
# Konna Watashitachi ga Nariyuki de Heroine ni Natta Kekka www (TV) Specials
# No score
# Score Failed
# Hello Carbot Specials: Pentastorm
# No score
# Score Failed
# Sore Ike! Anpanman: Anpanman to Santa-san e no Tegami
# Detail/2014_fall.csv
# 2014 SEASONS.SPRING
# No Game No Life
# Haikyuu!!
# JoJo no Kimyou na Bouken Part 3: Stardust Crusaders
# Mahouka Koukou no Rettousei
# Fairy Tail (2014)
# Black Bullet
# Date A Live II
# Mekakucity Actors
# Ping Pong the Animation
# Bokura wa Minna Kawai-sou
# Hitsugi no Chaika
# Gokukoku no Brynhildr
# Soredemo Sekai wa Utsukushii
# Isshuukan Friends.
# Mushishi Zoku Shou
# Mangaka-san to Assistant-san to The Animation
# Akuma no Riddle
# Love Live! School Idol Project 2nd Season
# Ryuugajou Nanana no Maizoukin
# Gochuumon wa Usagi desu ka?
# Sidonia no Kishi
# Seikoku no Dragonar
# Soul Eater NOT!
# Kanojo ga Flag wo Oraretara
# Dragon Ball Kai (2014)
# Initial D Final Stage
# Selector Infected WIXOSS
# Baby Steps
# Kamigami no Asobi
# Blade & Soul
# Break Blade
# Inugami-san to Nekoyama-san
# Kenzen Robo Daimidaler
# Captain Earth
# Yu☆Gi☆Oh! Arc-V
# Escha & Logy no Atelier: Tasogare no Sora no Renkinjutsushi
# M3: Sono Kuroki Hagane
# Fuuun Ishin Dai☆Shougun
# Kiniro no Corda: Blue♪Sky
# Kindaichi Shounen no Jikenbo Returns
# Cardfight!! Vanguard: Legion Mate-hen
# Mahou Shoujo Taisen
# Gudetama
# Lady Jewelpet
# Keroro
# Majin Bone
# Abarenbou Rikishi!! Matsutarou
# Marvel Disk Wars: The Avengers
# Kantoku Fuyuki Todoki
# Dragon Collection
# Tenkai Knights
# Pretty Rhythm: All Star Selection
# Hero Bank
# Pac-World
# Meshimase Lodoss-tou Senki: Sorette Oishii no?
# Oreca Battle
# World Fool News (TV)
# Duel Masters VS
# Lovely Movie: Itoshi no Muco Season 2
# GO-GO Tamagotchi!
# No score
# Score Failed
# KutsuDaru.
# No score
# Score Failed
# Neko no Dayan
# Neko Pitcher
# Choubakuretsu Ijigen Menko Battle: Gigant Shooter Tsukasa
# Himitsukessha Taka no Tsume EX
# Carino Coni
# Ohayou Hakushon Daimaou
# No score
# Score Failed
# Konchuu Monogatari Tentoumu Chu! to Mitsubachi Hatsu Chu!
# No score
# Score Failed
# Astar-eul Hyanghae Chaguchagu
# No score
# Score Failed
# Norasco (TV)
# No score
# Score Failed
# ColoColo Animal 2
# No score
# Score Failed
# Eungkka Sonata
# No score
# Score Failed
# Grami's Circus Show
# Hunter x Hunter (2011)
# Naruto: Shippuuden
# One Piece
# Nisekoi
# Meitantei Conan
# Diamond no Ace
# Tonari no Seki-kun
# Yowamushi Pedal
# Pokemon XY
# Nobunaga the Fool
# Crayon Shin-chan
# Aikatsu!
# Youkai Watch
# Doraemon (2005)
# Happiness Charge Precure!
# Future Card Buddyfight
# Furusato Saisei: Nippon no Mukashibanashi
# Sazae-san
# Nintama Rantarou
# Koukaku Kidoutai Nyuumon Arise
# Chibi Maruko-chan (1995)
# Sore Ike! Anpanman
# Ninja Hattori-kun (2012)
# Gaist Crusher
# Saikyou Ginga Ultimate Zero: Battle Spirits
# Chao Zhi Neng Zu Qiu
# Ojarumaru
# No score
# Score Failed
# Kamiusagi Rope: Warau Asa ni wa Fukuraitaru tte Maji ssuka!?
# Danchi Tomoo
# Hanakappa
# No score
# Score Failed
# Shiawase Haitatsu Taneko
# Xia Lan
# No score
# Score Failed
# Shimajirou no Wow!
# No score
# Score Failed
# Nyanfuru
# No score
# Score Failed
# Xiao Hua Xian
# No score
# Score Failed
# Tetsujin 28-gou Gao!
# Annyeong Jadoo
# No score
# Score Failed
# Gohan Kaijuu Pap
# Chuldong! Super Wings
# Porong Porong Pororo 5
# No score
# Score Failed
# Yowamushi Monsters
# No score
# Score Failed
# Ehon Yose
# Xiong Chumo: Conglin Zong Dong Yuan
# No score
# Score Failed
# Panpaka Pants
# No score
# Score Failed
# Tomodachi 8-nin
# No score
# Score Failed
# Ganbare! Oden-kun
# No score
# Score Failed
# Yi Kong Zhi Dian
# No score
# Score Failed
# Pakkororin
# Kkoma Bus Tayo 3
# Robocar Poli 3
# No score
# Score Failed
# Ppalgan Jajeongeo
# No score
# Score Failed
# Kijeu CSI
# No score
# Score Failed
# Yuhuwa Chingudeul 2
# No score
# Score Failed
# Wonder Balls
# No score
# Score Failed
# Can Wa Yu Tianchi Guaishou
# No score
# Score Failed
# Dudadakung
# No score
# Score Failed
# Konglong Laile
# No score
# Score Failed
# Bubble Cook Wonjeongdae
# No score
# Score Failed
# Nohjima Jeongsinjul
# No score
# Score Failed
# Kkureogi Kelatobseu Koliyo
# Noraneko
# Puchimas!!: Petit Petit iDOLM@STER
# Miss Monochrome The Animation: Soccer-hen
# Meitantei Conan: Toubousha Mouri Kogorou
# Chao You Bing
# Toki wa Meguru: Tokyo Station
# Wangpai Yushi
# Gakumon!: Ookami Shoujo wa Kujikenai
# Meisou! Underworld
# Kyoufu Shinbun (2014)
# Show By Rock!! x Joysound
# Moonrakers
# Shigeru
# Channel 5.5 2nd Season
# Qin Shi Mingyue: Kong Shan Niao Yu
# Shinrabanshou: Tenchi Shinmei no Shou
# Agukaru: Play with Ibaraki-hen
# 3-pun de Wakaru Koizumi Yakumo no Kaidan
# No score
# Score Failed
# KoSys! Kochira Keihime Tetsudou: Kouhou System-ka
# Momon's Sand Witch
# Kana Kana Kazoku x Himitsukessha Taka no Tsume Collaboration Film
# Zombie Ehon
# Kura Sushi
# Chogokin Hello Kitty
# Ao no Butai ni Omoi wo Yosete
# Si Ling Bianma: Shijie Caozong Zhe Recap
# No score
# Score Failed
# Ponkotsu Quest x Monsterz
# No score
# Score Failed
# Go! Go! Kadendanshi 2nd Season
# dwarf Movie Lab
# No score
# Score Failed
# Inuyama Kamiko no Kireigoto ja Owaranai!
# No score
# Score Failed
# Momon's Sand Witch Bangai-hen: Tanu no Kyuujitsu
# Oniwa no Soto
# No score
# Score Failed
# Ijigen Gattai Mojibakeru Z
# Bansoukousaten
# No score
# Score Failed
# Zhi Duoduo Qihuan Xingkong Zhi Lu
# No score
# Score Failed
# Dibetagurashi: Ahiru no Seikatsu - Ahiru no Sumu Shima
# No score
# Score Failed
# Bousai Keihatsu Douga
# No score
# Score Failed
# Shua Bing Nan De Gaoxiao Juchang
# No score
# Score Failed
# Hadopelagic
# No score
# Score Failed
# Koala no Bocchi
# No score
# Score Failed
# Xiongmao Shouzha
# No score
# Score Failed
# Shijiu Guo
# No score
# Score Failed
# Jian Meng Sanguo
# No score
# Score Failed
# Gongzhu Qian Qian: Liyi Pian
# Shingeki no Kyojin OVA
# Magi: Sinbad no Bouken
# Kidou Senshi Gundam Unicorn
# Seitokai Yakuindomo* OVA
# Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru OVA
# Haiyore! Nyaruko-san W: W ni Sayonara/Kono Onsen ni Koi no Konton wo
# Saikin, Imouto no Yousu ga Chotto Okashiinda ga. OVA
# Inari, Konkon, Koi Iroha. Inari, Konkon, Semishigure.
# Furueru Kuchibiru
# Chichiiro Toiki
# 12-sai.
# Ane Log: Moyako Neesan no Honpen wo Tobidashite Tomaranai Monologue
# Hayate no Gotoku! OVA
# Kyonyuu Kazoku Saimin
# Touhou Niji Sousaku Doujin Anime: Musou Kakyou Special
# Tennen Koi-iro Alcohol
# Furueru Kuchibiru Episode 0
# Pandra The Animation: Shiroki Yokubou Kuro no Kibou
# PeroPero☆Teacher
# Shin Sei Yariman Gakuen Enkou Nikki The Animation
# Kuraibito
# Renai Fuyou Gakuha The Animation
# Miss Monochrome The Animation: Manager
# Nerawareta Megami Tenshi Angeltia: Mamotta Ningen-tachi ni Uragirarete
# Oshaburi Announcer
# Enbi
# Rennyuu Tales The Animation
# Yariman Fudousan
# Konna ni Yasashiku Sareta no
# Okusama wa Michael
# Love es M The Animation
# Robot Atom
# No score
# Score Failed
# Ore to Issho ni Training
# No score
# Score Failed
# Paper Cranes Story: Kenta to Maiko
# Tamako Love Story
# Sora no Otoshimono Final: Eternal My Master
# Persona 3 the Movie 2: Midsummer Knight's Dream
# Koukaku Kidoutai Arise: Ghost in the Shell - Border:3 Ghost Tears
# Meitantei Conan Movie 18: Ijigen no Sniper
# Lupin the IIIrd: Jigen Daisuke no Bohyou
# Saint Seiya: Legend of Sanctuary
# Inazuma Eleven: Chou Jigen Dream Match
# 00:08
# Crayon Shin-chan Movie 22: Gachinko! Gyakushuu no Robo To-chan
# Nemure Omoigo, Sora no Shitone ni
# Ghost Messenger Movie
# Omoigumo
# No score
# Score Failed
# Taka no Tsume 7: Joou Heika no Jobuubu
# Congming de Yixiu Zhi Fan Dou Gongzhu
# No score
# Score Failed
# Panpaka Pants Movie: Bananan Oukoku no Hihou
# No score
# Score Failed
# Yuuto-kun ga Iku Movie
# No score
# Score Failed
# Planetarium Kamiusagi Rope: Orera Rocket Tobasu tte Maji ssuka!?
# No score
# Score Failed
# Norasco: Cinema Point Card-hen
# No score
# Score Failed
# Zhu Zhu Xia: Yong Chuang Juren Dao
# No score
# Score Failed
# Simgyeong
# No score
# Score Failed
# Mohuan Xian Zong (Movie)
# No score
# Score Failed
# Qian Ting Zong Dong Yuan 4: Zhangyu Giyu Ji
# No score
# Score Failed
# Sinbad Lixian Ji 2
# No score
# Score Failed
# Wo Shi Lang: Huolong Shanda Maoxian
# No score
# Score Failed
# Taikong Xiongmao Zongdongyuan
# No score
# Score Failed
# Xin Dilei Zhan: Shenyong Xiaozi
# No score
# Score Failed
# San Xiaoqiang
# No Game No Life Specials
# Danshi Koukousei no Nichijou Specials
# Chuunibyou demo Koi ga Shitai! Ren Specials
# Sword Art Online: Sword Art Offline - Extra Edition
# Little Busters! EX
# Mangaka-san to Assistant-san to The Animation Specials
# Kuroko no Basket: Mou Ikkai Yarimasen ka
# Kyoukai no Kanata: Mini Gekijou
# GJ-bu@
# Tonari no Seki-kun Specials
# Pokemon XY: Mega Evolution
# Freezing Vibration Specials
# Isshuukan Friends. Specials
# Witch Craft Works Specials
# Ryuugajou Nanana no Maizoukin: Nanana Nippon Mukashibanashi
# Sekai de Ichiban Tsuyoku Naritai! Specials
# Blade & Soul Specials
# White Album 2 Picture Drama
# Hikari no Megami
# Ane Log: Moyako Neesan no Honpen wo Tobidashite Tomaranai Monologue Specials
# Tamayura: More Aggressive - Ichinichi dake no Shuugakuryokou, nanode
# Aoki Hagane no Arpeggio: Ars Nova - Kirikumas
# Kidou Senshi Gundam Unicorn: Episode EX - Hyakunen no Kodoku
# Robot Girls Z Specials
# Strange+ Special
# Majokko Shimai no Yoyo to Nene Movie Extra: Hatsukoi - Mikako Komatsu
# Future Card Buddyfight Recap
# Mahou no Tenshi Creamy Mami no Otogibanashi
# No score
# Score Failed
# Yasai no Yousei: N.Y. Salad Special
# Detail/2014_spring.csv
# 2014 SEASONS.SUMMER
# Tokyo Ghoul
# Akame ga Kill!
# Sword Art Online II
# Zankyou no Terror
# Ao Haru Ride
# Gekkan Shoujo Nozaki-kun
# Barakamon
# Aldnoah.Zero
# Free! Eternal Summer
# Kuroshitsuji: Book of Circus
# Seireitsukai no Blade Dance
# Love Stage!!
# Rail Wars!
# Rokujouma no Shinryakusha!?
# Space☆Dandy 2nd Season
# Re:␣Hamatora
# Tokyo ESP
# DRAMAtical Murder
# Fate/kaleid liner Prisma☆Illya 2wei!
# Glasslip
# Sabage-bu!
# Himegoto
# Hanayamata
# Persona 4 the Golden Animation
# Majimoji Rurumo
# Jinsei
# Nobunaga Concerto
# Yami Shibai 2
# Futsuu no Joshikousei ga [Locodol] Yattemita.
# Shirogane no Ishi: Argevollen
# Yama no Susume Second Season
# Momo Kyun Sword
# Bakumatsu Rock
# Sengoku Basara: Judge End
# PriPara
# Shounen Hollywood: Holly Stage for 49
# Shin Strange+
# Choboraunyopomi Gekijou Dai Ni Maku Ai Mai Mii: Mousou Catastrophe
# Francesca
# Kidou Senshi Gundam-san
# Minarai Diva
# Maido! Urayasu Tekkin Kazoku
# Larva 3rd Season
# No score
# Score Failed
# Sumiko (TV)
# No score
# Score Failed
# Baby Gamba
# No score
# Score Failed
# Kotowaza Gundam-san
# No score
# Score Failed
# Choegang Top Plate Part 2
# No score
# Score Failed
# Hello Carbot
# No score
# Score Failed
# Biklonz
# Hunter x Hunter (2011)
# Naruto: Shippuuden
# One Piece
# Haikyuu!!
# JoJo no Kimyou na Bouken Part 3: Stardust Crusaders
# Mahouka Koukou no Rettousei
# Fairy Tail (2014)
# Meitantei Conan
# Diamond no Ace
# Dragon Ball Kai (2014)
# Pokemon XY
# Baby Steps
# Crayon Shin-chan
# Captain Earth
# Yu☆Gi☆Oh! Arc-V
# M3: Sono Kuroki Hagane
# Aikatsu!
# Youkai Watch
# Doraemon (2005)
# Kindaichi Shounen no Jikenbo Returns
# Cardfight!! Vanguard: Legion Mate-hen
# Mahou Shoujo Taisen
# Gudetama
# Happiness Charge Precure!
# Lady Jewelpet
# Future Card Buddyfight
# Furusato Saisei: Nippon no Mukashibanashi
# Keroro
# Majin Bone
# Abarenbou Rikishi!! Matsutarou
# Marvel Disk Wars: The Avengers
# Sazae-san
# Nintama Rantarou
# Chibi Maruko-chan (1995)
# Dragon Collection
# Tenkai Knights
# Sore Ike! Anpanman
# Ninja Hattori-kun (2012)
# Hero Bank
# Pac-World
# Gaist Crusher
# Oreca Battle
# Saikyou Ginga Ultimate Zero: Battle Spirits
# Ojarumaru
# Duel Masters VS
# No score
# Score Failed
# Kamiusagi Rope: Warau Asa ni wa Fukuraitaru tte Maji ssuka!?
# Danchi Tomoo
# Lovely Movie: Itoshi no Muco Season 2
# Hanakappa
# No score
# Score Failed
# Shiawase Haitatsu Taneko
# Xia Lan
# GO-GO Tamagotchi!
# No score
# Score Failed
# KutsuDaru.
# No score
# Score Failed
# Neko no Dayan
# Neko Pitcher
# No score
# Score Failed
# Shimajirou no Wow!
# Choubakuretsu Ijigen Menko Battle: Gigant Shooter Tsukasa
# Himitsukessha Taka no Tsume EX
# No score
# Score Failed
# Nyanfuru
# No score
# Score Failed
# Tetsujin 28-gou Gao!
# Annyeong Jadoo
# No score
# Score Failed
# Gohan Kaijuu Pap
# Carino Coni
# Chuldong! Super Wings
# Ohayou Hakushon Daimaou
# No score
# Score Failed
# Yowamushi Monsters
# No score
# Score Failed
# Ehon Yose
# Xiong Chumo: Conglin Zong Dong Yuan
# No score
# Score Failed
# Panpaka Pants
# No score
# Score Failed
# Tomodachi 8-nin
# No score
# Score Failed
# Ganbare! Oden-kun
# No score
# Score Failed
# Astar-eul Hyanghae Chaguchagu
# No score
# Score Failed
# Yi Kong Zhi Dian
# No score
# Score Failed
# Norasco (TV)
# No score
# Score Failed
# Pakkororin
# No score
# Score Failed
# ColoColo Animal 2
# No score
# Score Failed
# Ppalgan Jajeongeo
# No score
# Score Failed
# Kijeu CSI
# No score
# Score Failed
# Wonder Balls
# No score
# Score Failed
# Eungkka Sonata
# No score
# Score Failed
# Can Wa Yu Tianchi Guaishou
# No score
# Score Failed
# Konglong Laile
# No score
# Score Failed
# Bubble Cook Wonjeongdae
# No score
# Score Failed
# Nohjima Jeongsinjul
# Bishoujo Senshi Sailor Moon Crystal
# AkaKill! Gekijou
# Mijikamon
# Karen Senki
# Hacka Doll
# Buddy Complex: Daremo Shiranai Ashita e
# Kyoufu Shinbun (2014)
# Hua Jianghu: Bu Liang Ren
# M3: Sono Kuroki Hagane Recap
# Kidou Senshi Gundam-san (ONA)
# Toukiden Kiwami
# Channel 5.5 3rd Season
# Town Workers
# Sushi Ninja
# Onikiri Musume Saisen
# Qin Shi Mingyue: Luosheng Tangxia
# Inishie no Megami to Houseki no Ite
# Balgwanghaneun Hyeondaesa
# Channel 5.5 3rd Season Prologue
# Roll
# Ball yo Doko e Yuku
# In the Sea and near a Girl.
# No score
# Score Failed
# Kana Kana Kazoku
# No score
# Score Failed
# Kuiba Yao Xia Zhuan
# Majin Sentai Death Ranger: Ubawareta Pudding!
# On a Forest, in the Air
# No score
# Score Failed
# Mo Jing Lieren
# No score
# Score Failed
# Hakusai Anime Bangai-hen
# Sukui Agete Kurenai ka
# No score
# Score Failed
# Line Rangers
# No score
# Score Failed
# Owara Nai Chinkonka wo Utaou: Seinen no Uta
# No score
# Score Failed
# Koeda-chan Ohanashi
# No score
# Score Failed
# Miao Xiansheng: Huo Ze Kui Xiao Ren Chuan
# No score
# Score Failed
# Baozou Kongbu Gushi
# No score
# Score Failed
# McDull: Niu Hua Chen
# No score
# Score Failed
# Ming Ji 4: Chenfeng Zhuiyi
# No score
# Score Failed
# Cha A Er Zhong
# No score
# Score Failed
# Pao Fu Xiaojie 5th Season
# No score
# Score Failed
# Train Heroes Honjitsu mo Spin Out!
# Shingeki no Kyojin OVA
# Kiss x Sis
# Noragami OVA
# Ao Haru Ride OVA
# Magi: Sinbad no Bouken
# Non Non Biyori: Okinawa e Ikukoto ni Natta
# D-Frag!*
# Girls & Panzer: Kore ga Hontou no Anzio-sen desu!
# Ane Log: Moyako Neesan no Tomaranai Monologue
# Suisei no Gargantia: Meguru Kouro, Haruka
# Nozo x Kimi
# Baku Ane: Otouto Shibocchau zo! The Animation
# Terra Formars: Bugs 2-hen
# Shinryaku!! Ika Musume
# Mujaki no Rakuen
# Haikyuu!! Quest Picture Drama
# 12-sai.
# Ane Kyun!: Joshi ga Ie ni Kita!
# Chain Chronicle: Short Animation
# Tennen Koi-iro Alcohol
# Spocon!
# Mushibugyou OVA
# Furifure The Animation
# Mokkai Shiyo?
# Paizuri Cheerleader vs. Sakunyuu Ouendan!
# Fetikano!
# Kyonyuu Try!: Tanki Shuuchuu Chichi Momi Lesson
# Madonna: Kanjuku Body Collection
# Love Colon
# Sei Shoujo The Animation
# Injutsu no Yakata The Animation
# Mahou Shoujo wa Kiss Shite Kawaru
# Bakumatsu Rock: Mystery! Onsen Kaijiken ze yo!!
# Fantasista Stella
# Sakura Capsule
# Elite Jack!!
# Nekketsu Jinmen Inu: Life Is Movie
# No score
# Score Failed
# Kaseifu ga Ita.
# No score
# Score Failed
# Inui-san!
# No score
# Score Failed
# Ojiichan ga Nokoshite Kureta Mono: Moetemo Moenai? Moenikui!
# No score
# Score Failed
# Nobunaga-kun no Jitensha no Rule wo Mamoru no Ja
# No score
# Score Failed
# Nobunaga-kun no Minna de Yakusoku Hi no Youjin
# Omoide no Marnie
# K: Missing Kings
# Stand By Me Doraemon
# Pokemon Movie 17: Hakai no Mayu to Diancie
# Koukaku Kidoutai Arise: Ghost in the Shell - Border:4 Ghost Stands Alone
# New Initial D Movie: Legend 1 - Kakusei
# Yowamushi Pedal: Re:Ride
# Pokemon XY: Sora no Hahen
# K: Missing Kings - Manner Movie
# Uchuu Kyoudai: Number Zero
# Cardfight!! Vanguard Movie: Neon Messiah
# Pokemon: Pikachu, Kore Nan no Kagi?
# Long Zhi Gu: Poxiao Qibing
# Qin Shi Mingyue 3D: Dianying Longteng Wanli
# gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?
# Mori no Densetsu: Dai Ni Gakushou
# Mormorando
# Kuiba III: Zhanshen Jue Qi
# Sore Ike! Anpanman: Ringo Boy to Minna no Negai
# Maku
# Konna Watashitachi ga Nariyuki de Heroine ni Natta Kekka www
# No score
# Score Failed
# Maemilggot, Unsu Joeun Nal, Geurigo Bombom
# No score
# Score Failed
# Spo-chan Taiketsu: Youkai Daikessen
# No score
# Score Failed
# Shenmi Shijie Lixian Ji 2
# No score
# Score Failed
# Joseito (Movie)
# No score
# Score Failed
# Sore Ike! Anpanman: Tanoshiku Teasobi Mama ni Natta Kokin-chan!?
# No score
# Score Failed
# Taiyang Liu Zhu Wo
# No score
# Score Failed
# Shen Bi Ma Liang
# No score
# Score Failed
# Sai Er Hao Movie 4: Sheng Mo Zhi Zhan
# No score
# Score Failed
# Baixue Gongzhu: Airen Liliang
# No score
# Score Failed
# Xin Datou Er Zi He Xiao Tou Baba: Mimi Jihua
# No score
# Score Failed
# Kaixin Chaoren 2: Qi Yuan Xing Zhi Zhan
# No score
# Score Failed
# Gui Tu Zai Pao
# No score
# Score Failed
# Modeng Senlin: Meishi Zongdongyuan
# No score
# Score Failed
# Zhangyu Ge
# No score
# Score Failed
# Roco Wangguo 3: Sheng Long De Shouhu
# No score
# Score Failed
# Doraemon & Chinpui: Eri-sama Ai no Present Daisakusen
# No score
# Score Failed
# Pororo Sinnaneun Ujuyeohaeng
# Hanamonogatari
# Kill la Kill Specials
# No Game No Life Specials
# Gekkan Shoujo Nozaki-kun Specials
# Chuunibyou demo Koi ga Shitai! Ren: The Rikka Wars
# Kyoukai no Kanata: Shinonome
# Mushishi Zoku Shou: Odoro no Michi
# One Piece 3D2Y: Ace no shi wo Koete! Luffy Nakama Tono Chikai
# Chuunibyou demo Koi ga Shitai! Ren Specials
# Little Busters! EX
# Mangaka-san to Assistant-san to The Animation Specials
# Ano Natsu de Matteru: Bokutachi wa Koukou Saigo no Natsu wo Sugoshinagara, Ano Natsu de Matteiru.
# Fate/kaleid liner Prisma☆Illya 2wei! Specials
# Kyoukai no Kanata: Mini Gekijou
# Gokukoku no Brynhildr: Kara Sawagi
# Akame ga Kill! Recap
# Buddy Complex: Kanketsu-hen - Ano Sora ni Kaeru Mirai de
# Sabage-bu! Specials
# Bokura wa Minna Kawai-sou Specials
# Inugami-san to Nekoyama-san: Nekoyama-san to Onsen Ryokou
# Witch Craft Works Specials
# Love Live! School Idol Project: μ's →NEXT LoveLive! 2014 - Endless Parade Makuai Drama
# Futsuu no Joshikousei ga [Locodol] Yattemita.: Nagarekawa, Annai Shitemita.
# Selector Infected WIXOSS: Midoriko-san to Piruruku-tan
# Kenzen Robo Daimidaler Specials
# Pokemon XY: Koukoku no Princess Diancie
# Love Live! School Idol Project: μ's →NEXT LoveLive! 2014 - Endless Parade Encore Animation
# Space☆Dandy Picture Drama
# Girls & Panzer: Kore ga Hontou no Anzio-sen desu! - Fushou Akiyama Yukari no Sensha Kouza
# Break Blade: Virgins War
# Suisei no Gargantia: Puchitto Furikaerintia
# Robot Girls Z Specials
# Doraemon (2005) Specials
# Hana wa Saku: Touhoku ni Saku
# Medamayaki no Kimi Itsu Tsubusu?
# Nyamen: Tenkai Daiichi Joshi Koukou Bunka Matsuri Tokubetsu Eizou
# No score
# Score Failed
# Mono-darake!
# No score
# Score Failed
# Animax Taisou
# No score
# Score Failed
# Chikasugi Idol Akae-chan Specials
# Detail/2014_summer.csv
# 2014 SEASONS.WINTER
# Noragami
# Nisekoi
# Chuunibyou demo Koi ga Shitai! Ren
# Mikakunin de Shinkoukei
# D-Frag!
# Space☆Dandy
# Witch Craft Works
# Hamatora The Animation
# Sakura Trick
# Seitokai Yakuindomo*
# Mahou Sensou
# Tonari no Seki-kun
# Nourin
# Pupa
# Saikin, Imouto no Yousu ga Chotto Okashiinda ga.
# Inari, Konkon, Koi Iroha.
# Maken-Ki! Two
# Sekai Seifuku: Bouryaku no Zvezda
# Gin no Saji 2nd Season
# Hoozuki no Reitetsu
# Oneechan ga Kita
# Toaru Hikuushi e no Koiuta
# Nobunaga the Fool
# Buddy Complex
# SoniAni: Super Sonico The Animation
# Nobunagun
# Wizard Barristers: Benmashi Cecil
# Wake Up, Girls!
# Z/X: Ignition
# Saki: Zenkoku-hen
# Youkai Watch
# Strange+
# Pupipo!
# Happiness Charge Precure!
# Go! Go! 575
# Future Card Buddyfight
# Koukaku Kidoutai Nyuumon Arise
# Wooser no Sono Higurashi: Kakusei-hen
# Minna Atsumare! Falcom Gakuen
# Tesagure! Bukatsumono Encore
# Nyamen
# Nandaka Velonica
# Oniku Daisuki! Zeushi-kun
# Washimo
# Chou Zenmairobo: Patrasche
# 47 Todoufuken R
# No score
# Score Failed
# Nyanfuru
# No score
# Score Failed
# Xiao Hua Xian
# No score
# Score Failed
# Meitantei Rascal
# Porong Porong Pororo 5
# No score
# Score Failed
# Chikasugi Idol Akae-chan
# Kkoma Bus Tayo 3
# Robocar Poli 3
# No score
# Score Failed
# Pic-lele
# No score
# Score Failed
# Wonder Balls
# No score
# Score Failed
# Dudadakung
# No score
# Score Failed
# Nohjima Jeongsinjul
# No score
# Score Failed
# Kkureogi Kelatobseu Koliyo
# Hunter x Hunter (2011)
# Naruto: Shippuuden
# One Piece
# Kill la Kill
# Log Horizon
# Golden Time
# Kuroko no Basket 2nd Season
# Magi: The Kingdom of Magic
# Strike the Blood
# Nagi no Asu kara
# Tokyo Ravens
# Meitantei Conan
# Hajime no Ippo: Rising
# Diamond no Ace
# Yowamushi Pedal
# Uchuu Kyoudai
# Pokemon XY
# Kingdom 2nd Season
# Samurai Flamenco
# Toriko
# Crayon Shin-chan
# Gundam Build Fighters
# Inazuma Eleven Go: Galaxy
# Saint Seiya Omega
# Aikatsu!
# Yu☆Gi☆Oh! Zexal Second
# Phi Brain: Kami no Puzzle - Shukuteki! Rätsel-hen
# Cardfight!! Vanguard: Link Joker-hen
# Chibi☆Devi!
# Doraemon (2005)
# Pretty Rhythm: Rainbow Live
# Furusato Saisei: Nippon no Mukashibanashi
# Kuromajo-san ga Tooru!!
# Sazae-san
# Nintama Rantarou
# Chibi Maruko-chan (1995)
# Sore Ike! Anpanman
# Jewelpet Happiness
# Ninja Hattori-kun (2012)
# Gaist Crusher
# Saikyou Ginga Ultimate Zero: Battle Spirits
# Chao Zhi Neng Zu Qiu
# Ojarumaru
# Tanken Driland: 1000-nen no Mahou
# Duel Masters Victory V3
# No score
# Score Failed
# Kamiusagi Rope: Warau Asa ni wa Fukuraitaru tte Maji ssuka!?
# Balala Xiao Mo Xian: Qiji Wubu
# Mazinger ZIP!
# Danchi Tomoo
# Line Town
# Dibetagurashi: Ahiru no Seikatsu
# Hanakappa
# No score
# Score Failed
# Shiawase Haitatsu Taneko
# Xia Lan
# Oshiri Kajiri Mushi (TV) 2nd Season
# Tamagotchi! Miracle Friends
# Zhandou Wang Zhi Jufeng Zhan Hun 2
# No score
# Score Failed
# Shimajirou no Wow!
# Himitsukessha Taka no Tsume MAX
# No score
# Score Failed
# Tetsujin 28-gou Gao!
# Annyeong Jadoo
# No score
# Score Failed
# Kayoe! Chuugaku
# No score
# Score Failed
# Gohan Kaijuu Pap
# Chuldong! Super Wings
# No score
# Score Failed
# Yowamushi Monsters
# No score
# Score Failed
# Ehon Yose
# Xiong Chumo: Conglin Zong Dong Yuan
# No score
# Score Failed
# Panpaka Pants
# No score
# Score Failed
# Tomodachi 8-nin
# No score
# Score Failed
# Ganbare! Oden-kun
# No score
# Score Failed
# Yi Kong Zhi Dian
# No score
# Score Failed
# Pakkororin
# No score
# Score Failed
# Ppalgan Jajeongeo
# No score
# Score Failed
# Kijeu CSI
# No score
# Score Failed
# Yuhuwa Chingudeul 2
# No score
# Score Failed
# Caihong Xiong: Jizhan Huanying Guai
# No score
# Score Failed
# Can Wa Yu Tianchi Guaishou
# No score
# Score Failed
# Konglong Laile
# No score
# Score Failed
# Bubble Cook Wonjeongdae
# Yoku Wakaru Mahouka!
# Overlord: Oukoku no Kan-tachi - Drama CD-tsuki Tokusou-ban
# Paulette no Isu
# Wonder Momo
# Gunslinger Stratos
# Mijikamon Episode 0
# Zhongguo Jingqi Xiansheng
# Master of Torque
# Takarasagashi no Natsuyasumi
# Zuori Qing Kong Pilot
# Baku Tech! Bakugan Gachi Special
# Tuzki: Love Assassin
# X Maiden
# Nanocore
# Peeping Life: Shinkon-chan Kansai ni Irasshai
# Tobacco wa Dasai
# Channel 5.5
# Ponkotsu Quest x Gatchaman Special
# Xiao Yeyou
# I'm Stuck!!: Life of the Dead
# Kamiusagi Rope & Taka no Tsume Collab Eizou-hen
# Hana no Zundamaru: Junk
# No score
# Score Failed
# Ponkotsu Quest Specials
# No score
# Score Failed
# X Maiden: Izakaya Tamaki
# No score
# Score Failed
# Mochimochi Panda
# Momon's Sand Witch Episode 0
# Hadakya no Otonosama
# No score
# Score Failed
# Shiseido x Kamiusagi Rope
# Zenmaiji-kake no Truffe
# No score
# Score Failed
# Gonfu Tu Yu Cai Bao Gou
# No score
# Score Failed
# Wo De San Ti
# No score
# Score Failed
# Mou Inu Chuui
# Noragami OVA
# Hori-san to Miyamura-kun
# Natsume Yuujinchou: Itsuka Yuki no Hi ni
# Itadaki! Seieki♥
# Fate/kaleid liner Prisma☆Illya: Undoukai de Dance!
# Mikakunin de Shinkoukei: Kamoniku tte Midori-ppoi Aji ga Suru no ne.
# Yuusha ni Narenakatta Ore wa Shibushibu Shuushoku wo Ketsui Shimashita. OVA
# Tonari no Seki-kun OVA
# Toaru Kagaku no Railgun S: Daiji na Koto wa Zenbu Sentou ni Osowatta
# Choujigen Game Neptune The Animation: Yakusoku no Eien - True End
# Fella Pure: Mitarashi-san Chi no Jijou The Animation
# Futa-bu!
# Swing Out Sisters (2014)
# Kimi no Iru Machi OVA
# Oni Chichi 2: Revenge
# Okusama wa Moto Yariman
# Zetsumetsu Kigu Shoujo: Amazing Twins
# Yabai! Fukushuu Yami Site
# Hetalia: The Beautiful World Extra Disc
# Mou Hasamazu ni wa Irarenai♥: Hoshi ni Onegai shitara Konnani Okkiku Nacchatta!
# Wild Adapter
# Tokubetsu Jugyou 3 SLG The Animation
# Bikyaku Seido Kaichou Ai
# Imako System
# Oppai Infinity∞! The Animation
# Shiiba-san no Ura no Kao. with Imouto Lip
# Mitsuwano
# Cosplay Rakuen
# Puchimas!!: Petit Petit iDOLM@STER - Fuyu→Kotatsu←Haru
# Robot Atom
# Onegai☆Teacher: Experience
# No score
# Score Failed
# Onegai☆Twins: Relations
# Roku no Sekai
# No score
# Score Failed
# Pittarazu
# Sekaiichi Hatsukoi Movie: Yokozawa Takafumi no Baai
# Harmonie
# Sekaiichi Hatsukoi: Valentine-hen
# Giovanni no Shima
# Tiger & Bunny Movie 2: The Rising
# The iDOLM@STER Movie: Kagayaki no Mukougawa e!
# Wake Up, Girls! Shichinin no Idol
# Hakuouki Movie 2: Shikon Soukyuu
# Kuro no Su: Chronus
# Mouretsu Pirates: Abyss of Hyperspace
# Doraemon Movie 34: Shin Nobita no Daimakyou - Peko to 5-nin no Tankentai
# Avengers Confidential: Black Widow to Punisher
# Precure All Stars Movie New Stage 3: Eien no Tomodachi
# Ookii 1-nensei to Chiisana 2-nensei
# Tezuka Osamu no Buddha: Owarinaki Tabi
# Parol no Miraijima
# Wonder (Movie)
# Pretty Rhythm Movie: All Star Selection - Prism Show☆Best Ten
# Ulibyeol Ilhowa Eollugso
# Ginga Tetsudou 999: Akai Hoshi Betelgeuze - Inochi no Kagayaki
# Konohakaseki no Natsu
# Waiter
# No score
# Score Failed
# Shimajirou no Wow! Movie 2: Shimajirou to Kujira no Uta
# Xiong Chumo: Duo Bao Xiong Bing
# No score
# Score Failed
# Kamiusagi Rope x TOHO Cinemas (Movies)
# No score
# Score Failed
# Xi Yangyang Yu Hui Tailang: Fei Ma Qi Yu Ji
# No score
# Score Failed
# Toruru's Adventure
# Wormy
# No score
# Score Failed
# Train Heroes Movie
# No score
# Score Failed
# Blue Eyes: In Harbor Tale
# No score
# Score Failed
# FutureNova: Image Album
# No score
# Score Failed
# Xihu Chuanqi
# Mushishi: Hihamukage
# Free!: FrFr - Short Movie
# Chuunibyou demo Koi ga Shitai! Ren Specials
# Kuroko no Basket 2nd Season NG-shuu
# Shingeki no Kyojin Picture Drama
# Little Busters! EX
# Fate/kaleid liner Prisma☆Illya Specials
# Mikakunin de Shinkoukei: Mite. Are ga Watashitachi no Tomatteiru Ryokan yo.
# Kyoukai no Kanata: Mini Gekijou
# Takanashi Rikka Kai: Chuunibyou demo Koi ga Shitai! Movie Lite
# Itadaki! Seieki♥ Special
# Kamisama no Inai Nichiyoubi: Kioku
# Freezing Vibration Specials
# Maken-Ki! Two Specials
# Oneechan ga Kita: Hajimete no… Kitaa!
# Brothers Conflict: Setsubou
# Robot Girls Z
# Gatchaman Crowds: Embrace
# Witch Craft Works Specials
# Tsubasa to Hotaru
# Romantica Clock
# Sugar*Soldier
# Senki Zesshou Symphogear G: Senki Zesshou Shinai Symphogear
# Code Geass: Hangyaku no Lelouch R2 Picture Drama - Last Moratorium
# One Piece: Cry Heart
# Teekyuu 3 Specials
# Ore no Imouto ga Konnani Kawaii Wake ga Nai.: Ore no Imouto ga Konnani Eroge na Wake Nai
# Sekai de Ichiban Tsuyoku Naritai! Specials
# Hamatora The Animation: Saishuukai Chokuzen! Mao ga Okuru
# Pokemon Best Wishes! Season 2: Decolora Adventure - Iris vs. Ibuki! Dragon Master e no Michi!!
# Sengoku Musou SP: Sanada no Shou
# Gundam Build Fighters Specials
# Shin Kidou Senki Gundam Wing: Frozen Teardrop Picture Drama - Aratanaru Tatakai
# Inyouchuu Etsu Special
# Mou Hasamazu ni wa Irarenai♥: Hoshi ni Onegai shitara Konnani Okkiku Nacchatta! Special
# Danball Senki Wars: All Star Battle
# Hipira-kun Special
# Kirin the Noop
# No score
# Score Failed
# Crayon Shin-chan Specials
# No score
# Score Failed
# Lovely Movie: Itoshi no Muco Specials
# No score
# Score Failed
# Liv & Bell
# No score
# Score Failed
# Neppuu Kairiku Bushi Road: Kibou e no Michi
# No score
# Score Failed
# Xiong Chumo: Nianhuo
# Nakano Harada Kekkon Kyousoukyoku
# No score
# Score Failed
# En En Nikoli
# No score
# Score Failed
# Kanbee-kun ga Yuku
# No score
# Score Failed
# Overman King Gainer Recap
# No score
# Score Failed
# Mori no Hito to Shoutengu-chan
# No score
# Score Failed
# Lu Shidai Xinnian Fanwai Pian
# No score
# Score Failed
# Xin Datou Er Zi He Xiao Tou Baba: Ma Nian Xin Yuan
# Detail/2014_winter.csv
# 2015 SEASONS.FALL
# One Punch Man
# Noragami Aragoto
# Haikyuu!! Second Season
# Rakudai Kishi no Cavalry
# Owari no Seraph: Nagoya Kessen-hen
# Gakusen Toshi Asterisk
# Owarimonogatari
# Shinmai Maou no Testament Burst
# K: Return of Kings
# Taimadou Gakuen 35 Shiken Shoutai
# Ore ga Ojousama Gakkou ni "Shomin Sample" Toshite Gets♥Sareta Ken
# Shingeki! Kyojin Chuugakkou
# Kidou Senshi Gundam: Tekketsu no Orphans
# Sakurako-san no Ashimoto ni wa Shitai ga Umatteiru
# Subete ga F ni Naru
# Osomatsu-san
# Diabolik Lovers More,Blood
# Heavy Object
# Pokemon XY&Z
# Valkyrie Drive: Mermaid
# Gochuumon wa Usagi desu ka??
# Dance with Devils
# Yuru Yuri San☆Hai!
# Utawarerumono: Itsuwari no Kamen
# Comet Lucifer
# Hidan no Aria AA
# Concrete Revolutio: Choujin Gensou
# Young Black Jack
# Komori-san wa Kotowarenai!
# Lupin III (2015)
# Hacka Doll The Animation
# Lance N' Masques
# Starmyu
# Kowabon
# Anitore! EX
# Kagewani
# Garo: Guren no Tsuki
# Onsen Yousei Hakone-chan
# Teekyuu 6
# Soukyuu no Fafner: Dead Aggressor - Exodus Part 2
# Miss Monochrome The Animation 3
# Tantei Team KZ Jiken Note
# Fushigi na Somera-chan
# Kindaichi Shounen no Jikenbo Returns 2nd Season
# JK Meshi!
# Cardfight!! Vanguard G: GIRS Crisis-hen
# Ame-iro Cocoa: Rainy Color e Youkoso!
# Itoshi no Muco
# Brave Beats
# Mini Hama: Minimum Hamatora
# Shin Atashin'chi
# Kamisama Minarai: Himitsu no Cocotama
# DD Hokuto no Ken 2 Ichigo Aji+
# Ketsuekigata-kun! 3
# Peeping Life TV: Season 1??
# Neko nanka Yondemo Konai.
# Kyoufu! Zombie Neko
# Mini Van 2nd Season
# Zhandou Wang Zhi Jufeng Zhan Hun 3
# Oshiri Kajiri Mushi (TV) 4th Season
# Doushitemo Eto ni Hairitai
# No score
# Score Failed
# Neko no Dayan: Nihon e Iku
# No score
# Score Failed
# Dochamon Junior
# No score
# Score Failed
# Fuusen Inu Tinny 2nd Season
# No score
# Score Failed
# Zhu Zhu Xia: Wu Ling Shou Wei Zhe
# No score
# Score Failed
# Dou Long Zhanshi 3: Long Yin Zhi Zhan
# No score
# Score Failed
# Galaxy Kids
# No score
# Score Failed
# Todag Todag Kkomo
# No score
# Score Failed
# Jiayou Ba! San Er Ban
# No score
# Score Failed
# Kodomo Keiji Memetan
# No score
# Score Failed
# Biklonz 4th Season
# Naruto: Shippuuden
# One Piece
# Fairy Tail (2014)
# Dragon Ball Super
# Gintama°
# God Eater
# World Trigger
# Meitantei Conan
# Ushio to Tora (TV)
# Diamond no Ace: Second Season
# Crayon Shin-chan
# Yu☆Gi☆Oh! Arc-V
# Aikatsu!
# Youkai Watch
# Aquarion Logos
# PriPara
# Doraemon (2005)
# Go! Princess Precure
# Gudetama
# Furusato Saisei: Nippon no Mukashibanashi
# Sazae-san
# Nintama Rantarou
# Future Card Buddyfight Hundred
# Chibi Maruko-chan (1995)
# Sore Ike! Anpanman
# Battle Spirits: Burning Soul
# Jewelpet Magical Change
# Nar Doma
# Ojarumaru
# Duel Masters VSR
# Turning Mecard
# No score
# Score Failed
# Kamiusagi Rope: Warau Asa ni wa Fukuraitaru tte Maji ssuka!?
# Larva 3rd Season
# Hanakappa
# No score
# Score Failed
# Shiawase Haitatsu Taneko
# Xia Lan
# Neko Pitcher
# Good Morning!!! Doronjo
# No score
# Score Failed
# Shimajirou no Wow!
# No score
# Score Failed
# Bary-san no Imabari-ben Kouza
# No score
# Score Failed
# Omakase! Miracle Cat-dan
# No score
# Score Failed
# Nyanfuru
# Himitsukessha Taka no Tsume DO
# No score
# Score Failed
# Tetsujin 28-gou Gao!
# Annyeong Jadoo
# No score
# Score Failed
# Happy Jozy
# No score
# Score Failed
# Gohan Kaijuu Pap
# Chuldong! Super Wings
# No score
# Score Failed
# Yowamushi Monsters
# No score
# Score Failed
# Gra-P & Rodeo
# No score
# Score Failed
# Ehon Yose
# No score
# Score Failed
# Tomodachi 8-nin
# No score
# Score Failed
# Boo Boo Boy
# No score
# Score Failed
# Kotori Samba
# No score
# Score Failed
# Pakkororin
# No score
# Score Failed
# Xiao Hua Xian 2nd Season
# No score
# Score Failed
# Robocar Poli 4
# No score
# Score Failed
# Robot Trains
# No score
# Score Failed
# Jeong-geul-eseo Sal-anamgi: Maru Adventure
# No score
# Score Failed
# Fan Kai Zhe Yi Ye
# No score
# Score Failed
# Hello Carbot Season 2
# No score
# Score Failed
# Dudadakung 2nd Season
# No score
# Score Failed
# Robotex
# Momokuri
# Aishen Qiaokeli-ing...
# Kidou Senshi Gundam Thunderbolt
# Hetalia: The World Twinkle
# Nihon Animator Mihonichi
# Monster Strike
# Kanamewo
# Chu Feng: B.E.E
# Kare Baka: Wagahai no Kare wa Baka de R
# Robot Girls Z Plus
# Ling Yu
# Ponkotsuland Saga
# Jakusansei Million Arthur
# Tong Zhi Zhe
# Four Seasons: Fuuka to Nanami
# Hua Jianghu: Ling Zhu
# MILPOM★
# Shiguang Guiyu
# Hot Minute: Gudetama
# Zonmi-chan: Halloween☆Special Movie!
# Shen Ming Zhi Zhou
# Chou Kidougai-ku: Kashiwa-no-Ha
# Mirai e no Kakehashi: Bridge for Future
# Gokiburi Hime
# Elite Banana Banao
# No score
# Score Failed
# Isobe Isobee Monogatari: Ukiyo wa Tsurai yo (2015)
# Super Short Comics
# No score
# Score Failed
# Shi Wan Ge Leng Xiaohua Di 3rd Season
# Qin Shi Mingyue: Guoqing Tebie Pian
# Pride
# Bouningen Weekend
# Tokyo Cosmo
# Geki Drive
# Touhokutou, Juunana no Sora
# No score
# Score Failed
# Jii Coro Comic
# No score
# Score Failed
# Bokura no Ashita: Freeter no Genjou ni Kansuru Wakamono e no Shuuchi Kouhou Jigyou
# No score
# Score Failed
# Matsubara-kun: Mackie E no Ouen Message
# No score
# Score Failed
# Wanwanwan Coin
# No score
# Score Failed
# Kuusou Suizokukan
# No score
# Score Failed
# Sukekiyo × The Zemeckises Collab Animation
# No score
# Score Failed
# Faqiu Xian
# No score
# Score Failed
# Zhongguo Changshi Ban
# No score
# Score Failed
# Na Nian Na Tu Naxie Shi Er 2nd Season
# No score
# Score Failed
# Jedi Shi Ri
# No score
# Score Failed
# Renzhe Meng Jian Chuan
# No score
# Score Failed
# Bai Xiang Zheme Duo
# No score
# Score Failed
# Hi, Goodbye
# No score
# Score Failed
# Rabby CC: Carol de Xinling Shijie
# One Punch Man: Road to Hero
# Noragami Aragoto OVA
# Tokyo Ghoul: "Pinto"
# Kamisama Hajimemashita: Kako-hen
# High School DxD BorN: Yomigaeranai Fushichou
# Strike the Blood: Valkyria no Oukoku-hen
# Himouto! Umaru-chan OVA
# Kidou Senshi Gundam: The Origin
# Noblesse: Pamyeol-ui Sijak
# Big Order
# Triage X: Recollection XOXO
# Hantsu x Trash
# Nagato Yuki-chan no Shoushitsu: Owarenai Natsuyasumi
# Ane Yome Quartet
# Cyborg 009 VS Devilman
# Ano Ko to Ii Koto
# Ero Manga! H mo Manga mo Step-up♪
# Mesu Kyoushi 4: Kegasareta Kyoudan
# Rinkan Biyaku Chuudoku: Nigeba Nashi! 1428-nin no Seito Zenin ni Sex Sareru Reijou Sayaka
# Tsunpri
# Chicchana Onaka
# Magical Suite Prism Nana
# Taimanin Asagi 2
# Hifuu Katsudou Kiroku: The Sealed Esoteric History
# Kowaremono The Animation
# Creamy Pie
# Majuu Jouka Shoujo Utea
# Honoo no Haramase Motto! Hatsuiku! Karada Sokutei 2
# 12-sai. 2nd Season
# Colosseum no Senki: Another Story
# Busou Shoujotai: Blade Briders The Animation
# No score
# Score Failed
# Hero Company
# Robot Atom
# No score
# Score Failed
# The Planet of Stray Cats
# No score
# Score Failed
# Onosaka Konishi no O+K 2.5-jigen Animation 3rd Season
# Little Witch Academia: Mahoujikake no Parade
# Digimon Adventure tri. 1: Saikai
# Girls & Panzer Movie
# High☆Speed! Movie: Free! Starting Days
# Shisha no Teikoku
# Harmony
# Ajin Part 1: Shoudou
# Aoki Hagane no Arpeggio: Ars Nova Movie 2 - Cadenza
# Mahou Shoujo Madoka★Magica: Concept Movie
# Tamayura: Sotsugyou Shashin Part 3 - Akogare
# Wake Up, Girls! Beyond the Bottom
# Fw:Hamatora
# Girls & Panzer Movie: 3-pun Chotto de Wakaru!! Girls & Panzer
# Mitsuami no Kamisama
# Go! Princess Precure Movie: Go! Go!! Gouka 3-bondate!!!
# UFO Gakuen no Himitsu
# Mini Hama: Minimum Hamatora Movies
# Youkai Watch Movie 2: Enma Daiou to Itsutsu no Monogatari da Nyan!
# Alice in Dreamland
# Tobidasu PriPara: Mi~nna de Mezase! Idol☆Grand Prix
# Kidou Senshi Gundam-san (Movie)
# Sensou no Tsukurikata
# Chibi Maruko-chan Movie: Italia kara Kita Shounen
# Gamba: Gamba to Nakama-tachi
# The Snack World
# No score
# Score Failed
# Sollo Talchul Gwi
# Afternoon Class
# No score
# Score Failed
# Nar Doma Manner Movie
# No score
# Score Failed
# This Is My House
# No score
# Score Failed
# Long Zai Na Li?
# No score
# Score Failed
# Annyeong, Jeonwoochi! Dosoolrobotdaegyeoljeon
# No score
# Score Failed
# Quefa Mingzi de Changsuo
# No score
# Score Failed
# Tian Yan Chuanqi
# No score
# Score Failed
# Zang Ling Wangzhixue Yu Jingling
# No score
# Score Failed
# Pororo Movie: Keompyuteo Wang-gug Daemoheom
# No score
# Score Failed
# Tuzi Zhen De Huo Huli
# No score
# Score Failed
# Morengen
# No score
# Score Failed
# Jidi Da Fangong
# No score
# Score Failed
# Gulu Gulu Meirenyu
# No score
# Score Failed
# Dongbei Hua Ze Lei: Qi Yao Ezi
# No score
# Score Failed
# Shengdan Da Yingjia
# One Punch Man Specials
# Steins;Gate: Kyoukaimenjou no Missing Link - Divide By Zero
# Fate/stay night: Unlimited Blade Works 2nd Season - Sunny Day
# Kuroko no Basket: Saikou no Present desu
# High School DxD BorN: Ishibumi Ichiei Kanzen Kanshuu! Mousou Bakuyou Kaijo Original Video
# Owari no Seraph: The Beginning of the End
# Hibike! Euphonium: Kakedasu Monaka
# Owaranai Seraph: Nagoya-hen
# One Piece: Adventure of Nebulandia
# Fate/kaleid liner Prisma☆Illya 2wei Herz! Specials
# Aoharu x Kikanjuu: Kemono-tachi no Senjou da na!
# Shinmai Maou no Testament Burst Specials
# Gintama°: Umai-mono wa Atomawashi ni Suru to Yokodorisareru kara Yappari Saki ni Kue
# Pokemon XY: Mega Evolution
# Aria the Avvenire
# Valkyrie Drive: Mermaid Specials
# Bikini Warriors Special
# Servamp Specials
# One Piece: Long Ring Long Land-hen
# Code Geass: Boukoku no Akito 4 - Nikushimi no Kioku kara Picture Drama
# Wakaba*Girl: Onsen Tsukaritai
# Lupin III (2015) Specials
# Hetalia: The World Twinkle Specials
# Senki Zesshou Symphogear GX: Senki Zesshou Shinai Symphogear
# Classroom☆Crisis: Tabi no Haji wa Uwanuri
# Love Live! Kouhaku Special Anime
# Pokemon XY&Z: Subete no Nazo wo Tokiakase!
# Teekyuu 5 Specials
# Heavy Object: Dai 37 Kidou Seihi Daitai - Sakusen Kiroku
# Makura no Danshi: Sono Ato no Makura no Danshi
# Urawa no Usagi-chan: Natsu no Hi to, Bushitsu to, Tomodachi to
# Shinkyoku no Grimoire The Animation: Unico no Natsuyasumi
# Kindaichi Shounen no Jikenbo Returns 2nd Season: Akechi Keibu no Jikenbo
# Nanairo Kakumei
# Doraemon (2005) Specials
# Kimi no Sumu Machi
# Fushigi na Somera-chan: Hajimatteru yo! Sono Ato no Somera-chan!!
# Mahou Shoujo Elena DVD-BOX Special
# Mameshiba Gakuen
# Sinbad: Soratobu Hime to Himitsu no Shima Pilot
# Devilman Pilot Film
# No score
# Score Failed
# Liv & Bell
# No score
# Score Failed
# Ponkotsu Quest: Maou to Haken no Mamono-tachi Specials
# No score
# Score Failed
# Oidon to
# No score
# Score Failed
# Nar Doma Special
# Million Doll: Otaku Go Kouza
# No score
# Score Failed
# Undouki Kenshin Manual Taiou Taisou
# No score
# Score Failed
# Dab-eul Chaj-eun du Sonyeon
# No score
# Score Failed
# Dou Long Zhanshi Waizhuan
# No score
# Score Failed
# Oishiku Tsukurou! Puchipuchi Dance
# No score
# Score Failed
# Biklonz: Barbarian King Special
# No score
# Score Failed
# Sore Ike! Anpanman: Baikinman to Suteki na Christmas Cake
# Detail/2015_fall.csv
# 2015 SEASONS.SPRING
# Shokugeki no Souma
# Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka
# Owari no Seraph
# Yahari Ore no Seishun Love Comedy wa Machigatteiru. Zoku
# Plastic Memories
# Kekkai Sensen
# Fate/stay night: Unlimited Blade Works 2nd Season
# High School DxD BorN
# Yamada-kun to 7-nin no Majo
# Nisekoi:
# Ore Monogatari!!
# Gintama°
# Hibike! Euphonium
# Grisaia no Rakuen
# Arslan Senki (TV)
# Punch Line
# Danna ga Nani wo Itteiru ka Wakaranai Ken 2 Sure-me
# Triage X
# Denpa Kyoushi
# Diamond no Ace: Second Season
# Nagato Yuki-chan no Shoushitsu
# Sidonia no Kishi: Daikyuu Wakusei Seneki
# Baby Steps 2nd Season
# Mikagura Gakuen Kumikyoku (TV)
# Kyoukai no Rinne
# Show By Rock!!
# Etotama
# Hello!! Kiniro Mosaic
# Gunslinger Stratos The Animation
# Re-Kan!
# Uta no☆Prince-sama♪ Maji Love Revolutions
# Koukaku Kidoutai Arise: Alternative Architecture
# Houkago no Pleiades (TV)
# Ame-iro Cocoa
# Mahou Shoujo Lyrical Nanoha ViVid
# Teekyuu 4
# Vampire Holmes
# Urawa no Usagi-chan
# Takamiya Nasuno desu! Teekyuu Spin-off
# Kaitou Joker 2nd Season
# Future Card Buddyfight Hundred
# Battle Spirits: Burning Soul
# Tesagure! Bukatsumono Spin-off Purupurun Sharumu to Asobou
# Jewelpet Magical Change
# BAR Kiraware Yasai
# Nar Doma
# Usavich Zero
# Duel Masters VSR
# Pikaia!
# Eikoku Ikka, Nihon wo Taberu
# Gon 2nd Season
# Good Morning!!! Doronjo
# No score
# Score Failed
# Tamagotchi! Tamatomo Daishuu GO
# Nyuru Nyuru!! Kakusen-kun 2nd Season
# No score
# Score Failed
# Omakase! Miracle Cat-dan
# Himitsukessha Taka no Tsume DO
# No score
# Score Failed
# Happy Jozy
# No score
# Score Failed
# Panpaka Pants O-New!
# No score
# Score Failed
# Funassyi no Funafunafuna Biyori
# No score
# Score Failed
# Kotori Samba
# No score
# Score Failed
# Washimo 3rd Season
# ...
# Ganbare! Lulu Lolo 2nd Season
# No score
# Score Failed
# ColoColo Animal 2
# No score
# Score Failed
# Ppalgan Jajeongeo
# No score
# Score Failed
# G Fighters
# No score
# Score Failed
# Fan Kai Zhe Yi Ye
# No score
# Score Failed
# Hello Carbot
# Anime de Wakaru Shinryounaika
# Nihon Animator Mihonichi
# Princess Connect!
# Okaasan ni Naisho
# Obake no Dokurou
# Kotowaza Gundam-san (ONA)
# MILPOM★ Pilot
# Master of Torque 2
# Shinkansen Henkei Robo Shinkalion
# No score
# Score Failed
# Yong Zhe Da Maoxian
# Qin Shi Mingyue Tebie Pian: Di Zi Jiang Xi
# Fast Week
# Ushinawareta Choushoku
# Agukaru: Play with Ibaraki-hen Episode 0
# Tansa Quest!
# Kana Kana Kazoku: Shinnen no Goaisatsu
# Nanocore: NG Scenes - Nano's Daily Life
# No score
# Score Failed
# Lalala Lala-chan
# No score
# Score Failed
# BeyWarriors: Cyborg
# No score
# Score Failed
# Chao Shen Xueyuan: Shen yu Shen
# No score
# Score Failed
# Yumearu Ugoku Ehon
# No score
# Score Failed
# Lalala Lala-chan Mini
# Sara Ke Puccho
# No score
# Score Failed
# Funassyi to Yukaina Kyoudai
# No score
# Score Failed
# Fettu to Ccine to Gummi Seijin
# No score
# Score Failed
# Na Nian Na Tu Naxie Shi Er
# No score
# Score Failed
# Baozou LOL
# No score
# Score Failed
# Bao Dan Jing Ying
# No score
# Score Failed
# Nonty
# Kuroshitsuji: Book of Murder
# High School DxD New: Oppai, Tsutsumimasu!
# Nisekoi OVA
# Trinity Seven: Nanatsu no Taizai to Nana Madoushi
# Haikyuu!! Lev Genzan!
# Hori-san to Miyamura-kun
# Seitokai Yakuindomo* OVA
# Kidou Senshi Gundam: The Origin
# Yuru Yuri Nachuyachumi!
# Imawa no Kuni no Alice
# Mankitsu Happening
# Hitsugi no Chaika: Nerawareta Hitsugi/Yomigaeru Iseki
# Diabolik Lovers OVA
# Witch Craft Works: Takamiya-kun to Imouto no Warudakumi
# Strike Witches: Operation Victory Arrow
# Hyakka Ryouran: Samurai After
# Futa-bu!!
# Senran Kagura Estival Versus: Mizugi-darake no Zenyasai
# Hoozuki no Reitetsu OVA
# Oni Chichi 2: Harvest
# 12-sai.
# Kanojo wa Dare to demo Sex Suru.
# Lovely x Cation The Animation
# Shouwa Genroku Rakugo Shinjuu: Yotarou Hourou-hen
# Sei Yariman Sisters Pakopako Nikki The Animation
# Fukubiki! Triangle: Futaba wa Atafuta ♥
# Iinari! Saimin Kanojo
# Mushibugyou OVA
# Shabura Rental: Ecchi na Oneesan to no Eroero Rental Obenkyou The Animation
# Boku no Yayoi-san
# Buta no Gotoki Sanzoku ni Torawarete Shojo wo Ubawareru Kyonyuu Himekishi & Onna Senshi
# Demonion: Gaiden
# Ienai Koto The Animation
# Ikenai Koto The Animation
# Nosewasure: Onna Kyoushi Chuuzenji Ayano no Inutsu na Kore kara
# No score
# Score Failed
# Trojan wo Jibun no Te de
# No score
# Score Failed
# Fushouji no Mizen Boushi: Saihatsu Boushi Series
# No score
# Score Failed
# Sore Ike! Anpanman: Happy Otanjoubi Series
# Psycho-Pass Movie
# Kyoukai no Kanata Movie 1: I'll Be Here - Kako-hen
# Hana to Alice: Satsujin Jiken
# Aoki Hagane no Arpeggio: Ars Nova Movie 1 - DC
# Aki no Kanade
# Appleseed Alpha
# Ongaku Shoujo
# Sidonia no Kishi Movie
# Doraemon Movie 35: Nobita no Space Heroes
# Precure All Stars Movie: Haru no Carnival♪
# PriPara Movie: Mi~nna Atsumare! Prism☆Tours
# Kumi to Tulip
# Happy ComeCome
# No score
# Score Failed
# Saenggakboda Markeun
# Yuuyake Dandan
# Yi Wan Nian Yi Hou
# Shi Wan Ge Leng Xiaohua Movie 1
# Such a Good Place to Die
# Tsukiyo & Opal
# Kidou Senshi Gundam-san: Gekijou Manner CM
# Xiong Chumo: Xue Ling Xiong Feng
# Tu Xia Zhi Qing Li Chuanshuo
# I Wanna Be Your Friend
# Xi Yangyang Yu Hui Tailang: Yang Nian Xi Yangyang
# No score
# Score Failed
# Shimajirou no Wow! Movie 3: Shimajirou to Ookinaki
# Sanuki Eiga-sai Opening Eizou
# No score
# Score Failed
# Youyu Bi
# No score
# Score Failed
# Chuuchuu
# No score
# Score Failed
# Guanzhao
# No score
# Score Failed
# Mole Zhuang Yuan 3: Mohuan Lieche Da Maoxian
# No score
# Score Failed
# Long Qi Xia
# No score
# Score Failed
# Miniforce: Saeloun Agdangui Seubgyeog
# No score
# Score Failed
# Chuang Tang Tu 2: Fengkuang Maxi Tuan
# No score
# Score Failed
# Xinnian Lai La: Da Nao Chuxi
# Saenai Heroine no Sodatekata: Ai to Seishun no Service-kai
# Free! Eternal Summer: Kindan no All Hard!
# Grisaia no Kajitsu Specials
# Bokura wa Minna Kawai-sou: Hajimete no
# Shinmai Maou no Testament Specials
# Fate/kaleid liner Prisma☆Illya 2wei! Specials
# Seireitsukai no Blade Dance Specials
# Pokemon XY: Mega Evolution
# Shirobako Specials
# Sabage-bu! Specials
# Bokura wa Minna Kawai-sou Specials
# Aldnoah.Zero Extra Archives
# Yoku Wakaru Mahouka! - Saiseitte Nani?
# Yama no Susume Second Season Specials
# Hyakka Ryouran: Samurai After Specials
# Tsubasa to Hotaru (2015)
# Dog Days Recap
# Military!: Tamatama Shoumetsu Suru Shiroki Hikari!
# Meitantei Conan: Kinga Shinnen Mouri Kogorou
# One Piece 4D
# Rolling☆Girls: Chibi☆Rolling☆Girls Korokoro Gekijou
# The iDOLM@STER Cinderella Girls: Special Program
# Saki Achiga-hen: Episode of Side-A - Kuro no Tanjoubi
# Gundam: G no Reconguista - From the Past to the Future
# Soukyuu no Fafner: Dead Aggressor - Exodus Special
# Mahou Shoujo Lyrical Nanoha StrikerS Picture Drama
# Nekota no Koto ga Kininatte Shikatanai.
# Minna Atsumare! Falcom Gakuen SC Special
# Ima, Futari no Michi
# Love Live! μ's Go→Go! LoveLive! 2015: Dream Sensation!
# No score
# Score Failed
# Crayon Shin-chan Specials
# Dededen
# Onnanoko tte.
# No score
# Score Failed
# Konigiri-kun
# No score
# Score Failed
# Liv & Bell
# Stand By Me Doraemon Specials
# No score
# Score Failed
# Beads no Mori no Rabi
# Dai 13-kai Indies Anime Festa OP
# No score
# Score Failed
# Xin Datou Er Zi He Xiao Tou Baba: Caoyuan Qiyu
# Detail/2015_winter.csv
# 2016 SEASONS.FALL
# Haikyuu!! Karasuno Koukou vs. Shiratorizawa Gakuen Koukou
# Yuri!!! on Ice
# Bungou Stray Dogs 2nd Season
# 3-gatsu no Lion
# Drifters
# Watashi ga Motete Dousunda
# Keijo!!!!!!!!
# Nanbaka
# Ajin Part 2
# Hibike! Euphonium 2
# Occultic;Nine
# Flip Flappers
# Natsume Yuujinchou Go
# Shuumatsu no Izetta
# Okusama ga Seitokaichou!+!
# Mahou Shoujo Ikusei Keikaku
# WWW.Working!!
# Kidou Senshi Gundam: Tekketsu no Orphans 2nd Season
# Udon no Kuni no Kiniro Kemari
# Fune wo Amu
# Pokemon Sun & Moon
# Trickster: Edogawa Ranpo "Shounen Tanteidan" yori
# All Out!!
# Bloodivores
# Gi(a)rlish Number
# ViVid Strike!
# Touken Ranbu: Hanamaru
# Cheating Craft
# To Be Hero
# Brave Witches
# Lostorage Incited WIXOSS
# Magic-Kyun! Renaissance
# Shakunetsu no Takkyuu Musume
# Gakuen Handsome
# Uta no☆Prince-sama♪ Maji Love Legend Star
# Stella no Mahou
# Show By Rock!! #
# Kiitarou Shounen no Youkai Enikki
# Long Riders!
# Soushin Shoujo Matoi
# Nobunaga no Shinobi
# ClassicaLoid
# Bubuki Buranki: Hoshi no Kyojin
# Bernard-jou Iwaku.
# Tiger Mask W
# Ao Oni The Animation
# Soul Buster
# 12-sai.: Chicchana Mune no Tokimeki 2nd Season
# Digimon Universe: Appli Monsters
# Monster Hunter Stories: Ride On
# Teekyuu 8
# Anitore! XX: Hitotsu Yane no Shita de
# Mahou Shoujo Nante Mou Ii desu kara. Second Season
# Nazotokine
# Cardfight!! Vanguard G Next
# Idol Memories
# Koneko no Chi: Ponponra Daibouken
# Ame-iro Cocoa in Hawaii
# Nyanbo!
# Sengoku Choujuu Giga: Kou
# Hagane Orchestra
# Time Bokan 24
# Kaitou Joker 4th Season
# Bishoujo Yuugi Unit Crane Game Girls Galaxy
# Heybot!
# 3-nen D-gumi Glass no Kamen
# Kamigami no Ki
# No score
# Score Failed
# Yasamura Yasashi no Yasashii Sekai
# Balala Xiao Mo Xian Zhi: Feiyue Cai Ling Bao
# Tama & Friends: Uchi no Tama Shirimasen ka?
# PePePePengiin
# No score
# Score Failed
# Kimoshiba
# No score
# Score Failed
# Neko no Dayan: Fushigi Gekijou
# No score
# Score Failed
# Pittanko! Nekozakana
# No score
# Score Failed
# Ohayou! Kokekkou-san
# No score
# Score Failed
# Lalala Lala-chan: Patapata Daisensou
# No score
# Score Failed
# Dochamon Junior 2
# No score
# Score Failed
# Zhu Zhu Xia: Meng Xiang Shou Wei Zhe
# No score
# Score Failed
# Magic Adventures: The Crystal of Dark
# No score
# Score Failed
# Athlon Tobot 2
# No score
# Score Failed
# Shouwang Zhengfeng
# No score
# Score Failed
# Senba Xingfu Dao
# No score
# Score Failed
# Biklonz 5th Season
# Naruto: Shippuuden
# One Piece
# JoJo no Kimyou na Bouken Part 4: Diamond wa Kudakenai
# Saiki Kusuo no Ψ-nan
# Dragon Ball Super
# Sousei no Onmyouji
# Meitantei Conan
# Days
# Aggressive Retsuko
# Crayon Shin-chan
# Yu☆Gi☆Oh! Arc-V
# Beyblade Burst
# Youkai Watch
# Regalia: The Three Sacred Stars
# PriPara
# Aikatsu Stars!
# Doraemon (2005)
# Mahoutsukai Precure!
# Gudetama
# Furusato Saisei: Nippon no Mukashibanashi
# Puzzle & Dragons Cross
# Sazae-san
# Nintama Rantarou
# Chibi Maruko-chan (1995)
# Future Card Buddyfight Triple D
# Sore Ike! Anpanman
# Kamisama Minarai: Himitsu no Cocotama
# Neko Neko Nihonshi
# Rilu Rilu Fairilu: Yousei no Door
# Bonobono (TV 2016)
# Shounen Ashibe: Go! Go! Goma-chan
# Ojarumaru
# Sinbi Apartment: Ghost Ball Bimil
# Duel Masters VSRF
# Battle Spirits: Double Drive
# No score
# Score Failed
# Kamiusagi Rope: Warau Asa ni wa Fukuraitaru tte Maji ssuka!?
# Hanakappa
# No score
# Score Failed
# Shiawase Haitatsu Taneko
# Aware! Meisaku-kun
# Asa da yo! Kaishain
# No score
# Score Failed
# CoCO & NiCO
# No score
# Score Failed
# Kamiwaza Wanda
# No score
# Score Failed
# Shimajirou no Wow!
# Turning Mecard W
# No score
# Score Failed
# Nameko: Sekai no Tomodachi
# No score
# Score Failed
# Freaky Highschool
# No score
# Score Failed
# Gohan Kaijuu Pap
# No score
# Score Failed
# PJ Berri no Mogumogu Munyamunya
# No score
# Score Failed
# Yowamushi Monsters
# No score
# Score Failed
# Telemonster
# No score
# Score Failed
# Ehon Yose
# No score
# Score Failed
# Gra-P & Rodeo II
# No score
# Score Failed
# Mikan Seijin Arawaru
# No score
# Score Failed
# Otona no Ikkyuu-san
# No score
# Score Failed
# Tomodachi 8-nin
# No score
# Score Failed
# Chobitto Zukan
# No score
# Score Failed
# Pakkororin
# Kkoma Bus Tayo 4
# Power Battle Watch Car Season 2
# No score
# Score Failed
# Muzumuzu Eighteen
# No score
# Score Failed
# Capsule Boy
# No score
# Score Failed
# Ma-eum-uisoli
# No score
# Score Failed
# Kemy Tamheomdae
# No score
# Score Failed
# SofyRuby
# No score
# Score Failed
# Xin Hulu Xiongdi
# No score
# Score Failed
# Steel Fire Brigade Fire Robo
# No score
# Score Failed
# Fan Kai Zhe Yi Ye
# No score
# Score Failed
# DinoCore
# No score
# Score Failed
# Hello Carbot Season 4
# Getsuyoubi no Tawawa
# Pokemon Generations
# Koro-sensei Quest!
# Shingeki no Bahamut: Genesis - Short Story
# Elsword: El-ui Yeoin
# Guomin Laogong Dai Huijia
# Luger Code 1951
# Closers: Side Blacklambs
# Huyao Xiao Hongniang: Beishan Yaodi
# Inazuma Eleven: Outer Code
# Yareruko! Densha Ecchi
# CMFU Xueyuan: Wangzi Peng Peng Qiu
# Masamune Datenicle
# Girlfriend (Note)
# Akashic Re:cords
# Wu Shan Wu Xing
# Monster Strike: Zoku Saishuu-banashi - Pandora no Hako
# Elsword: Ain-ui Gieog Animation
# Monster Strike: Rain of Memories
# Dongguo Xiaojie
# Cinderella Girls Gekijou: 5-shuunen Kinen Short Anime
# Kingsglaive: FFXV Fan Kansha Tokubetsu Movie
# Crayon Shin-chan Gaiden: Omocha Wars
# Ling Yu 4th Season
# Fune wo Amu Yokoku
# Hua Jianghu: Bei Mo Ting
# Gijinka de Manabo!
# No score
# Score Failed
# Star Ocean: Anamnesis
# Higanjima X
# Xianjing Chuanshuo RO: Shouhu Yongheng de Ai
# Nineko Gelée
# No score
# Score Failed
# Junlin Chengxia
# Chuuko Video-ya no Onna Tenin X
# Kuro-Nikuru Girls
# 100% Pascal-sensei
# Master of Torque: Epilogue
# Gingirl
# Haha no Supporter
# Kamigami no Ki: Xmas Special
# Season's Greetings from dwarf
# No score
# Score Failed
# Midori-chan
# No score
# Score Failed
# Nusheng Sushe Richang
# Alita De Shi Lian
# No score
# Score Failed
# GJ8man
# No score
# Score Failed
# Levain Cup x Kamiusagi Rope
# No score
# Score Failed
# Kamiusagi Rope x Wacoal
# Acca-kun no ACCA Kouza
# No score
# Score Failed
# He Nü'er De Richang
# No score
# Score Failed
# Zhu Zhu Xia: Fan Wai - Pin Zhuang Tegong Dui
# No score
# Score Failed
# Mouretsu 50 Ototarou
# No score
# Score Failed
# Fantastic World
# No score
# Score Failed
# Shaonian Jinyiwei Xuzhang
# No score
# Score Failed
# Yichan Xiao Heshang
# No score
# Score Failed
# Haru no Niji no Soushiki
# No score
# Score Failed
# Shengsi Huifang
# No score
# Score Failed
# Na Nian Na Tu Naxie Shi Er 3rd Season
# No score
# Score Failed
# Qiang Ling Jihua
# No score
# Score Failed
# Salangeun Oneuldo Malgeum
# No score
# Score Failed
# Jibian Ying Meng
# No score
# Score Failed
# Ali Bu Ta Gushi Ji
# No score
# Score Failed
# Cafe Wingcle
# No score
# Score Failed
# Nengli Youxian Gongsi
# No score
# Score Failed
# Spicy Boy Z
# No score
# Score Failed
# I Laohu You
# No score
# Score Failed
# Tiancai Lianmeng
# No score
# Score Failed
# Ju Shu 5 Sui Hua
# Yahari Ore no Seishun Love Comedy wa Machigatteiru. Zoku OVA
# Strike the Blood II
# Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka OVA
# Akatsuki no Yona OVA
# Monster Musume no Iru Nichijou OVA
# Kubikiri Cycle: Aoiro Savant to Zaregotozukai
# Gintama°: Aizome Kaori-hen
# Fairy Tail OVA (2016)
# Seitokai Yakuindomo* OVA
# Kidou Senshi Gundam: The Origin
# Kamisama Hajimemashita: Kamisama, Shiawase ni Naru
# Ajin OVA
# Black Clover: Jump Festa 2016 Special
# Shoujo Ramune
# Toshi Densetsu Series
# Baki: Most Evil Death Row Convicts Special Anime
# Bikini Warriors OVA
# Amakano
# Ano Ko to Ii Koto
# Fella Hame Lips
# Otokonoko ♂ Delivery
# Diamond no Ace: Second Season OVA
# 8-shaku 8-wa Kerakumeguri: Igyou Kaikitan The Animation
# Oide yo! Shiritsu Yarimakuri Gakuen
# Imouto to Sono Yuujin ga Ero Sugite Ore no Kokan ga Yabai
# Kowaremono: Risa Plus The Animation
# Iizuka-senpai x Blazer: Ane Kyun! yori The Animation
# Tenchi Muyou! Ryououki 4th Season
# Pretty x Cation 2 The Animation
# Bokura no Sex
# Saimin Class
# Taimanin Asagi 3
# Trick or Alice
# Trickster: Edogawa Ranpo "Shounen Tanteidan" yori OVA
# Kimi no Mana wa Rina Witch
# Ecchi na Shintai Sokutei Anime Edition
# Seikatsu Shidou!! Anime Edition
# Imakara Atashi......
# Hataraku Otona no Renai Jijou The Animation
# "Eiyuu" Kaitai
# Gravity Daze The Animation: Ouverture
# No score
# Score Failed
# Himitsu no Pommepomme-chan
# Kono Sekai no Katasumi ni
# Orange: Mirai
# Ansatsu Kyoushitsu: 365-nichi no Jikan
# Suki ni Naru Sono Shunkan wo. Kokuhaku Jikkou Iinkai
# Gantz:O
# Koutetsujou no Kabaneri Movie 1: Tsudou Hikari
# Kuroko no Basket Movie 3: Winter Cup - Tobira no Mukou
# KanColle Movie
# Kuroko no Basket Movie 2: Winter Cup - Namida no Saki e
# Kiniro Mosaic: Pretty Days
# Chain Chronicle: Haecceitas no Hikari Part 1
# Kagerou Daze: In a Day's
# Pop in Q
# Tokyo One Piece Tower: Tongari Shima no Dai Hihou
# Ginga Kikoutai Majestic Prince Movie: Kakusei no Idenshi
# Kidou Keisatsu Patlabor: Reboot
# Cyborg 009: Call of Justice 1
# Monster Strike The Movie: Hajimari no Basho e
# Cyborg 009: Call of Justice 3
# Mahoutsukai Precure! Movie: Kiseki no Henshin! Cure Mofurun!
# Cyborg 009: Call of Justice 2
# Zegapain ADP
# Joleobban
# Saiki Kusuo no Ψ-nan Manner Movie
# Youkai Watch Movie 3: Soratobu Kujira to Double Sekai no Daibouken da Nyan!
# Cure Miracle to Mofurun no Mahou Lesson
# Yoiko no Rekishi Anime: Ookina Kabu (Kabu)
# Chen-Kuro Gakuen
# Kine-Pass Gekijou
# Wo Shi Na Zha
# Kaibutsu Gakushou
# No score
# Score Failed
# Complex x Complex
# No score
# Score Failed
# The Snack World: Hitogirai no Renny
# No score
# Score Failed
# Sanpou Shoujo
# Pochi Hana
# No score
# Score Failed
# Baise Suidao
# No score
# Score Failed
# Bate
# No score
# Score Failed
# Kung Fu Si Xia
# No score
# Score Failed
# Xindongfang Shen Wa (Movie)
# No score
# Score Failed
# Fengkuang Chou Xiao Ya
# No score
# Score Failed
# Chaoji Youeryuan
# No score
# Score Failed
# Play House
# No score
# Score Failed
# Rexue Lei Feng Xia: Jiqing Yingjiu
# No score
# Score Failed
# Si Du Chishui
# No score
# Score Failed
# Jungle Taxi
# Fate/Grand Order: First Order
# Musaigen no Phantom World: Mizutama no Kiseki
# Getsuyoubi no Tawawa Specials
# Masou Gakuen HxH Specials
# Tanaka-kun wa Itsumo Kedaruge Specials
# Meitantei Conan: Episode One - Chiisaku Natta Meitantei
# Danganronpa 3: Monokuma Gekijou
# Keijo!!!!!!!! Specials
# Zutto Mae kara Suki deshita. Kokuhaku Jikkou Iinkai: Kinyoubi no Ohayou
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 for SEASON in Scraper.SEASONS.__members__.values():
#       3 #for SEASON in [Scraper.SEASONS.SPRING, Scraper.SEASONS.SUMMER, Scraper.SEASONS.WINTER]:
#       4     print(YEAR, SEASON)
# ----> 5     AutomateDetails(YEAR, SEASON)
#
# Cell In[4], line 9, in AutomateDetails(YEAR, SEASON)
#       6 newRow = None
#       8 try:
# ----> 9     soup = Scraper.scrape(row.Link)
#      10     output = DetailsPage.parse(soup)
#      11     output['Title'] = row.Title
#
# File ~\Documents\DATA102-Data_Mining\Scraping\src\Scraper.py:32, in Scraper.scrape(url)
#      29 @staticmethod
#      30 def scrape(url : str) -> BeautifulSoup:
#      31     #include a delay per get() to avoid DDOS
# ---> 32     Scraper.delay()
#      34     response = requests.get(url)
#      35     if response.status_code != requests.status_codes.codes.all_ok:
#
# File ~\Documents\DATA102-Data_Mining\Scraping\src\Scraper.py:27, in Scraper.delay()
#      25 @staticmethod
#      26 def delay():
# ---> 27     time.sleep(np.random.rand() * 10 + Scraper.MINIMUM_DELAY)
#
# KeyboardInterrupt:

# %% [markdown]
# # Statistics [1] Summary and [2] Submissions

# %%
assert False

# %% [markdown]
# ## 1. Get the Scores of Every Anime in Season and Year

# %%
def AutomateStatSummary(YEAR:int, SEASONS:Scraper.SEASONS) -> pd.DataFrame:
    df_StatSummary = None
    
    for _, row in pd.read_csv(f'Season/{YEAR}_{SEASON.value}.csv', index_col=0).iterrows():
        URL = f'{row.Link}/stats'
        print(URL)
    
        try:
            soup = Scraper.scrape(URL)
            data = StatisticsSummaryPage.parse(soup)
            data['Title'] = row.Title
        
            if df_StatSummary is None: 
                df_StatSummary = pd.DataFrame([data])
            else:
                df_StatSummary = pd.concat([df_StatSummary, pd.DataFrame([data])], ignore_index=True)
        except Exception as e:
            print(f'ERROR URL {e}')
        
    filename = f'Statistics/Summary/{YEAR}_{SEASON.value}.csv'
    print(filename)
    df_StatSummary.to_csv(filename)
    
    return df_StatSummary

# %%
#YEAR = 2024
#SEASON = Scraper.SEASONS.FALL

for YEAR in np.arange(2014, 2019):
    for SEASON in Scraper.SEASONS.__members__.values():
        print(YEAR, SEASON)

        if SEASON in []:
            pass
        else:
            AutomateStatSummary(YEAR, SEASON)

# %% [markdown]
# ## 2. Scrape the Latest Viewership across <= 100 Pages for a Given Title

# %%
def AutomateStatSubmissions(TITLE : str, LINK : str):
    df_Statistics = None
    
    for i in np.arange(0, 75*100, 75):
        try:
            URL = f'{LINK}/stats?show={i}#members'
            print(URL)
    
            soup = Scraper.scrape(URL)
    
            
            if df_Statistics is None:
                df_Statistics = StatisticsSubmissionPage.parseAsDf(soup)
            else:
                df_Statistics = pd.concat([df_Statistics, StatisticsSubmissionPage.parseAsDf(soup)], ignore_index=True)
            
        except Exception as e:
            print(f'END {e}')
            break
    
    filename = f'Statistics/Submissions/{TITLE}.csv'
    df_Statistics.to_csv(filename)
    print(filename)

# %% [markdown]
# ### Try EVA

# %%
EVA = pd.read_csv('Season/1995_fall.csv', index_col=0).loc[0]

AutomateStatSubmissions(TITLE=EVA.Title, LINK=EVA.Link)
