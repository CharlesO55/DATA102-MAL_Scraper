# %%
import pandas as pd
import numpy as np
from os import listdir
import re

import matplotlib.pyplot as plt

# %%
EXPORT_FOLDER = '../MP/Files/'

# %%
def CompileCSV(FOLDER : str):
    FILENAMES = [f'{FOLDER}/{file}' for file in listdir(FOLDER)[1:]]
    FILENAMES
    
    output = None
    
    for f in FILENAMES:
        if f[-4:] != '.csv':
            continue
    
        df = None
    
        ID, NAME = f.split('/')[-1].strip('.csv').split('_')
    
        df = pd.read_csv(f)
        df['Personnel_ID'] = int(ID)
        df['Personnel_Name'] = NAME
    
    
        if output is None:
            output = df.copy()
        else:
            output = pd.concat([output, df])

    return output

# %% [markdown]
# # Voice Actors

# %%
FOLDER = 'Roles/VA'

FILENAMES = [f'{FOLDER}/{file}' for file in listdir(FOLDER)[1:]]
len(FILENAMES)
# Out:
# 14599

# %%
df_VA = CompileCSV(FOLDER).reset_index().drop(columns=['index'])

# %%
df_VA.drop(columns=['Link', 'CharacterLink'], inplace=True)
df_VA.rename(columns={
    'ID': 'Anime_ID',
    'CharacterID' : 'Character_ID',
    'CharacterRole' : 'Role',
    'CharacterFavorites' : 'Character_Favorites',
                     }, inplace=True)
df_VA
# Out:
#         Anime_ID                 Title   Type  Season    Year  \
# 0           3588            Soul Eater     TV  Spring  2008.0
# 1             27         Trinity Blood     TV  Spring  2005.0
# 2             20                Naruto     TV    Fall  2002.0
# 3             47                 Akira  Movie     NaN  1988.0
# 4            523      Tonari no Totoro  Movie     NaN  1988.0
# ...          ...                   ...    ...     ...     ...
# 425145      1960    Sore Ike! Anpanman     TV    Fall  1988.0
# 425146      1960    Sore Ike! Anpanman     TV    Fall  1988.0
# 425147      1960    Sore Ike! Anpanman     TV    Fall  1988.0
# 425148      1960    Sore Ike! Anpanman     TV    Fall  1988.0
# 425149       820  Ginga Eiyuu Densetsu    OVA     NaN  1988.0
#
#                      Character  Character_ID        Role  Character_Favorites  \
# 0                    Excalibur         13046  Supporting                 1574
# 1              Nightroad, Abel          1672        Main                  974
# 2               Gekkou, Hayate          7738  Supporting                   54
# 3                     Yamagata         20463  Supporting                   13
# 4             Kusakabe, Tatsuo          8047  Supporting                   25
# ...                        ...           ...         ...                  ...
# 425145                Numatchi        114765  Supporting                    0
# 425146              Marron-kun        196687  Supporting                    0
# 425147       Kaginoko Key-chan        197241  Supporting                    0
# 425148               Kittelion        197260  Supporting                    0
# 425149  von Kreutzer, Katerose         13857  Supporting                   18
#
#         Personnel_ID    Personnel_Name
# 0              10002     Rajkai Zoltán
# 1              10002     Rajkai Zoltán
# 2              10002     Rajkai Zoltán
# 3              10002     Rajkai Zoltán
# 4              10002     Rajkai Zoltán
# ...              ...               ...
# 425145             9  Mitsuishi Kotono
# 425146             9  Mitsuishi Kotono
# 425147             9  Mitsuishi Kotono
# 425148             9  Mitsuishi Kotono
# 425149             9  Mitsuishi Kotono
#
# [425150 rows x 11 columns]

# %% [markdown]
# ### Remove Irrelevant Characters

# %%
MIN_FAVORITES = 1
df_VA = df_VA[df_VA.Character_Favorites >= MIN_FAVORITES]
df_VA.shape
# Out:
# (281013, 11)

# %% [markdown]
# ## Extract the VA IDs

# %%
df_PersonnelsVA = df_VA.copy()
df_PersonnelsVA.Character = df_PersonnelsVA.Character.replace(',', '', regex=True)
df_PersonnelsVA = pd.merge(df_PersonnelsVA.groupby(['Personnel_ID', 'Personnel_Name'])[['Character', 'Character_ID', 'Title', 'Anime_ID', 'Year']].agg(list).reset_index().set_index('Personnel_ID'),
         df_PersonnelsVA.groupby(['Personnel_ID']).Year.max(),
         on='Personnel_ID',
        how='left').rename(columns={'Year_x': 'Year', 'Year_y': 'Latest_Work'})

df_PersonnelsVA.to_pickle(EXPORT_FOLDER+ 'Personnels_VA.pkl')
df_PersonnelsVA
# Out:
#                 Personnel_Name  \
# Personnel_ID
# 1                Seki Tomokazu
# 2              Sugita Tomokazu
# 3               Yukino Satsuki
# 4                   Hirano Aya
# 5             Suzumura Kenichi
# ...                        ...
# 59879            Haruka Megumi
# 59883             Matalon Adam
# 59884              Balkan Liza
# 59890           Shinohara Isao
# 59896             Tarján Péter
#
#                                                       Character  \
# Personnel_ID
# 1             [Shinazugawa Sanemi, Hoshimiya Rekka, Honekawa...
# 2             [Sakata Gintoki, Smart Ansem, Himejima Gyoumei...
# 3             [Shimura Tae, Shimura Tae, Hiiragi, Shihouin Y...
# 4             [Antoinette Marie, Antoinette Marie, Kazamaki ...
# 5             [Okita Sougo, Iguro Obanai, Hinawa Takehisa, S...
# ...                                                         ...
# 59879                     [Ichinose Riko, Ichinose Riko, Reina]
# 59883                                              [Asuka Ryou]
# 59884                                  [Mizuno Ami, Mizuno Ami]
# 59890                                                [Rokushou]
# 59896                                      [Narrator, Narrator]
#
#                                                    Character_ID  \
# Personnel_ID
# 1             [151149, 140499, 8261, 8079, 73589, 2514, 2606...
# 2             [672, 251334, 151146, 187171, 119733, 33788, 1...
# 3             [2944, 2944, 19023, 908, 87115, 151102, 908, 1...
# 4             [1701, 1701, 256815, 6273, 5186, 14117, 5186, ...
# 5             [2282, 151148, 133771, 42711, 194489, 51153, 2...
# ...                                                         ...
# 59879                                     [46677, 46677, 39814]
# 59883                                                    [4092]
# 59884                                              [2366, 2366]
# 59890                                                   [19502]
# 59896                                            [36309, 36309]
#
#                                                           Title  \
# Personnel_ID
# 1             [Kimetsu no Yaiba Movie: Mugen Jou-hen, Enen n...
# 2             [3-nen Z-gumi Ginpachi-sensei, Nageki no Boure...
# 3             [3-nen Z-gumi Ginpachi-sensei, Gintama on Thea...
# 4             [Versailles no Bara (Movie), Verbara Mini!, Ma...
# 5             [3-nen Z-gumi Ginpachi-sensei, Kimetsu no Yaib...
# ...                                                         ...
# 59879         [Rin x Sen + Ran -> Sem: Cross Mix, Ran->Sem: ...
# 59883                                    [Devilman: Tanjou-hen]
# 59884         [Bishoujo Senshi Sailor Moon SuperS, Bishoujo ...
# 59890                                                 [Medarot]
# 59896          [Pokemon Movie 01: Mewtwo no Gyakushuu, Pokemon]
#
#                                                        Anime_ID  \
# Personnel_ID
# 1             [59192, 51818, 59980, 59914, 59226, 55830, 568...
# 2             [54757, 60619, 59192, 60083, 59406, 59914, 589...
# 3             [54757, 59688, 55823, 56784, 57864, 56785, 539...
# 4             [52967, 60783, 59632, 56894, 60063, 56538, 497...
# 5             [54757, 59192, 51818, 50855, 57217, 49785, 557...
# ...                                                         ...
# 59879                                      [18525, 10458, 8654]
# 59883                                                    [2354]
# 59884                                               [1239, 532]
# 59890                                                    [1138]
# 59896                                                [528, 527]
#
#                                                            Year  Latest_Work
# Personnel_ID
# 1             [2025.0, 2025.0, 2025.0, 2025.0, 2025.0, nan, ...       2025.0
# 2             [2025.0, 2025.0, 2025.0, 2025.0, 2025.0, 2025....       2025.0
# 3             [2025.0, 2024.0, 2024.0, 2024.0, 2024.0, 2024....       2025.0
# 4             [2025.0, 2025.0, nan, 2024.0, 2024.0, 2024.0, ...       2025.0
# 5             [2025.0, 2025.0, 2025.0, 2024.0, 2024.0, 2024....       2025.0
# ...                                                         ...          ...
# 59879                                  [2013.0, 2011.0, 2010.0]       2013.0
# 59883                                                  [1987.0]       1987.0
# 59884                                          [1995.0, 1994.0]       1995.0
# 59890                                                  [1999.0]       1999.0
# 59896                                          [1998.0, 1997.0]       1998.0
#
# [12451 rows x 7 columns]

# %% [markdown]
# ### Continue Cleaning df_VA

# %%
df_VA['Character_Favorites'].plot(kind='hist', bins=25, edgecolor='black', alpha=0.7)
plt.title('Histogram of Favorites')
plt.xlabel('Character_Favorites')
plt.show()

# %%
df_VA.Role.value_counts()
# Out:
# Role
# Supporting    199078
# Main           81935
# Name: count, dtype: int64

# %%
df_VA = pd.get_dummies(df_VA, columns=['Role'])

# %%
df_VA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 281013 entries, 0 to 425149
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Anime_ID             281013 non-null  int64
#  1   Title                281013 non-null  object
#  2   Type                 280592 non-null  object
#  3   Season               182287 non-null  object
#  4   Year                 280592 non-null  float64
#  5   Character            281013 non-null  object
#  6   Character_ID         281013 non-null  int64
#  7   Character_Favorites  281013 non-null  int64
#  8   Personnel_ID         281013 non-null  int64
#  9   Personnel_Name       281013 non-null  object
#  10  Role_Main            281013 non-null  bool
#  11  Role_Supporting      281013 non-null  bool
# dtypes: bool(2), float64(1), int64(4), object(5)
# memory usage: 24.1+ MB

# %%
df_VA.to_csv(EXPORT_FOLDER + 'VA_Raw.csv')

# %%
df_VA_MBA = pd.DataFrame(df_VA.groupby('Anime_ID')[['Title', 'Personnel_ID', 'Personnel_Name', 'Character']].agg(list))
df_VA_MBA['Title'] = df_VA_MBA['Title'].apply(lambda x : x[0])

df_VA_MBA.to_pickle(EXPORT_FOLDER + 'MBA_VA.pkl')
df_VA_MBA
# Out:
#                                                       Title  \
# Anime_ID
# 1                                              Cowboy Bebop
# 5                           Cowboy Bebop: Tengoku no Tobira
# 6                                                    Trigun
# 7                                        Witch Hunter Robin
# 8                                            Bouken Ou Beet
# ...                                                     ...
# 61211                                   Mayonaka Heart Tune
# 61227         Girls & Panzer: Motto Love Love Sakusen desu!
# 61276     Mikata ga Yowasugite Hojo Mahou ni Tesshiteita...
# 61286     Digimon Adventure 25-shuunen Kinen PV: Digimon...
# 61295            Kidou Senshi Gundam: GQuuuuuuX - Beginning
#
#                                                Personnel_ID  \
# Anime_ID
# 1         [10004, 10020, 10020, 10021, 10024, 10024, 100...
# 5         [10004, 10028, 10030, 10155, 10155, 1019, 1059...
# 6         [10021, 1006, 1025, 1025, 10696, 1096, 1097, 1...
# 7         [10593, 1088, 1090, 10, 11920, 1268, 1286, 12,...
# 8         [112, 1138, 145, 1526, 201, 201, 259, 357, 447...
# ...                                                     ...
# 61211                                 [12041, 24413, 48122]
# 61227                      [10765, 17007, 17009, 885, 9593]
# 61276                                               [55585]
# 61286                [125, 16635, 28889, 316, 387, 87, 937]
# 61295     [11661, 23249, 410, 41648, 46241, 46833, 5142, 8]
#
#                                              Personnel_Name  \
# Anime_ID
# 1         [Vasconcellos Jorge, Patiño Marco, Patiño Marc...
# 5         [Vasconcellos Jorge, Atala Yamil, Ramirez Alfo...
# 6         [Vilchis José Gilberto, Forstadt Rebecca, Magn...
# 7         [Auer Dominik, Magnaghi Debora, Pacotto Emanue...
# 8         [Midorikawa Hikaru, Cason Chri, Grant Tiffany,...
# ...                                                     ...
# 61211            [Ookubo Rumi, Itou Miku, Suzushiro Sayumi]
# 61227     [Kayano Ai, Ozaki Mami, Nakagami Ikumi, Iguchi...
# 61276                                   [Umeda Shuuichirou]
# 61286     [Hirata Hiroaki, Hanae Natsuki, Yamaya Yoshita...
# 61295     [Kurosawa Tomoyo, Yamashita Seiichirou, Kawada...
#
#                                                   Character
# Anime_ID
# 1         [Bob, Solensan, Asimov, Vicious, Spiegel, Spik...
# 5         [Bob, Spiegel, Spike, Black, Jet, Jobim, Anton...
# 6         [the Hornfreak, Midvalley, Elizabeth, Vash the...
# 7         [Sakaki, Haruto, Sena, Robin, Doujima, Yurika,...
# 8         [Zenon, Grunide, Beet, Slade, Zenon, Shagi, Sh...
# ...                                                     ...
# 61211         [Himekawa, Nene, Uzuki, Shinobu, Kirino, Iko]
# 61227     [Takebe, Saori, Isuzu, Hana, Akiyama, Yukari, ...
# 61276                                         [Ygret, Alec]
# 61286     [Takaishi, Takeru, Yagami, Taichi, Hida, Iori,...
# 61295     [Yuzuriha, Amate, Olivette, Xavier, Bull, Chal...
#
# [10901 rows x 4 columns]

# %% [markdown]
# # Staff

# %%
FOLDER = 'Roles/Staff'

FILENAMES = [f'{FOLDER}/{file}' for file in listdir(FOLDER)[1:]]
len(FILENAMES)

# %%
df_Staff = CompileCSV(FOLDER).reset_index().drop(columns=['index'])
df_Staff

# %%
df_Staff.drop(columns=['Link'], inplace=True)
df_Staff.rename(columns={'ID':'Anime_ID'}, inplace=True)

# %% [markdown]
# ## Extract the Staff IDs

# %%
df_Staff

# %%
df_PersonnelsStaff = df_Staff.copy()
df_PersonnelsStaff = pd.merge(df_PersonnelsStaff.groupby(['Personnel_ID', 'Personnel_Name'])[['Title', 'Anime_ID', 'Type', 'Year', 'Score', 'Members']].agg(list).reset_index().set_index('Personnel_ID'),
         df_PersonnelsStaff.groupby(['Personnel_ID']).Year.max(),
         on='Personnel_ID',
        how='left').rename(columns={'Year_x': 'Year', 'Year_y': 'Latest_Work'})

df_PersonnelsStaff.to_pickle('Roles_Extracted/Personnels_Staff.pkl')
df_PersonnelsStaff

# %% [markdown]
# ### Continue cleaning

# %%
df_Staff.info()

# %% [markdown]
# ### Although some Anime Scores are null, their Members are all complete.

# %%
df_Staff[df_Staff.Score.isna()]

# %% [markdown]
# ## One Hot Encode the Roles

# %%
def filter_strings(strings, exclude_words, replace_words):
    filtered_strings = set()  
    
    for s in strings:
        if any(word in s for word in exclude_words):
            continue

        if any(word in s for word in replace_words):
            for w in replace_words:
                s = s.replace(w, '')
            
        filtered_strings.add(s)
    
    return list(filtered_strings)

# %%
ROLES = filter_strings(df_Staff.Roles, ['(', ',', ')', 'Original Creator'], [])
ROLES

# %%
df_OneHotStaffRoles = pd.DataFrame(columns=ROLES)

for role_String in df_Staff.Roles:
    df_OneHotStaffRoles.loc[len(df_OneHotStaffRoles)] = [1 if r in role_String else 0 for r in ROLES]

df_OneHotStaffRoles.head()

# %%
print(df_OneHotStaffRoles.sum().sort_values(ascending=False))

df_OneHotStaffRoles.sum().sort_values(ascending=False)[:20].plot(kind='bar', edgecolor='black', alpha=0.7)
plt.title('Top 20 Staff Roles')
plt.show()

# %%
df_Staff = df_Staff.reset_index().drop(columns=['index', 'Roles']).join(
    df_OneHotStaffRoles
)
df_Staff

# %%
df_Staff.to_csv(EXPORT_FOLDER + 'Staff_Raw.csv')

# %%
df_Staff_MBA = df_Staff.copy()
df_Staff_MBA['Role'] = df_Staff_MBA.iloc[:,9:].idxmax(axis=1).str.replace('class_', '')

df_Staff_MBA = df_Staff_MBA[['Anime_ID', 'Title', 'Role', 'Personnel_ID', 'Personnel_Name']].groupby('Anime_ID').agg(list)
df_Staff_MBA['Title'] = df_Staff_MBA['Title'].apply(lambda x : x[0])
df_Staff_MBA.to_pickle(EXPORT_FOLDER + 'MBA_Staff.pkl')
df_Staff_MBA
