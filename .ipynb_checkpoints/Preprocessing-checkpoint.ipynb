# %% [markdown]
# # TO DO
# Most of the pages have already been scraped and parsed into .csv files.
#
# Open these, clean them and interpret the data in any meaningful way.
#
# 1. Ensure the datatype is correct.
# 2. Ensure the null, NaN, default is correct.
# 3. Collapse redundant info : Genres = Genre

# %%
import pandas as pd
import os

# %%
FOLDER = 'Detail'

FILENAMES = [f'{FOLDER}/{file}' for file in os.listdir('Detail')[1:]]
FILENAMES
# Out:
# ['Detail/1995_fall_sample.csv',
#  'Detail/2024_fall-Copy1.csv',
#  'Detail/2024_fall.csv',
#  'Detail/2024_spring_sample.csv']

# %%
print(FILENAMES[1])
df = pd.read_csv(FILENAMES[1], index_col=0)
# Out:
# Detail/2024_fall-Copy1.csv

# %%
df
# Out:
#                                    Japanese  \
# 0                                     ダンダダン
# 1                           Re:ゼロから始める異世界生活
# 2                     ブルーロック VS. U-20 JAPAN
# 3                                      うずまき
# 4                         BLEACH 千年血戦篇-相剋譚-
# ..                                      ...
# 241                        『デリコズ・ナーサリー』育児日誌
# 242  逃走中 グレートミッション マイカとラビの総力取材 月世界一の逃走者は誰だ！
# 243                         ラブライブ！スーパースター!!
# 244        クリスマス特別編「クリスマスってみた」アニメ『ユーチューニャー』
# 245                                   あなのなか
#
#                                                English            Type  \
# 0                                           Dan Da Dan          ['TV']
# 1    Re:ZERO -Starting Life in Another World- Season 3          ['TV']
# 2                                   Blue Lock Season 2          ['TV']
# 3                          Uzumaki: Spiral into Horror          ['TV']
# 4       Bleach: Thousand-Year Blood War - The Conflict          ['TV']
# ..                                                 ...             ...
# 241                                                NaN  ['TV Special']
# 242                                                NaN  ['TV Special']
# 243       Love Live! Superstar!! Season 3 (TV Special)  ['TV Special']
# 244                                                NaN  ['TV Special']
# 245                                                NaN  ['TV Special']
#
#     Episodes            Status                         Aired      Premiered  \
# 0         12   Finished Airing   Oct 4, 2024 to Dec 20, 2024  ['Fall 2024']
# 1         16  Currently Airing              Oct 2, 2024 to ?  ['Fall 2024']
# 2         14   Finished Airing   Oct 6, 2024 to Dec 28, 2024  ['Fall 2024']
# 3          4   Finished Airing  Sep 28, 2024 to Oct 19, 2024  ['Fall 2024']
# 4         14   Finished Airing   Oct 5, 2024 to Dec 28, 2024  ['Fall 2024']
# ..       ...               ...                           ...            ...
# 241        1   Finished Airing                  Oct 10, 2024            NaN
# 242        1   Finished Airing                  Nov 10, 2024            NaN
# 243        6   Finished Airing  Oct 20, 2024 to Nov 24, 2024            NaN
# 244        1   Finished Airing                  Dec 24, 2024            NaN
# 245        1   Finished Airing                   Oct 9, 2024            NaN
#
#                      Broadcast  \
# 0       Fridays at 00:26 (JST)
# 1    Wednesdays at 22:30 (JST)
# 2     Saturdays at 23:30 (JST)
# 3                      Unknown
# 4     Saturdays at 23:00 (JST)
# ..                         ...
# 241                        NaN
# 242                        NaN
# 243                        NaN
# 244                        NaN
# 245                        NaN
#
#                                              Producers    Licensors  ...  \
# 0    ['Aniplex', 'Dentsu', 'Shogakukan-Shueisha Pro...    ['GKIDS']  ...
# 1    ['AT-X', 'Magic Capsule', 'Memory-Tech', 'Haku...  None found,  ...
# 2    ['TV Asahi', 'Lantis', 'Kodansha', "Toy's Fact...  None found,  ...
# 3                                   ['Production I.G']  None found,  ...
# 4    ['Pierrot', 'TV Tokyo', 'Aniplex', 'Dentsu', '...  None found,  ...
# ..                                                 ...          ...  ...
# 241                                        None found,  None found,  ...
# 242                                        None found,  None found,  ...
# 243                                        None found,  None found,  ...
# 244                                        None found,  None found,  ...
# 245                                            ['NHK']  None found,  ...
#
#                                        Related_Entries  \
# 0    ['Sequel (TV) Dandadan 2nd Season', 'Adaptatio...
# 1    ['Prequel (TV) Re:Zero kara Hajimeru Isekai Se...
# 2    ['Prequel (TV) Blue Lock', 'Adaptation (Novel)...
# 3                   ['Adaptation (Manga) Uzumaki', '']
# 4    ['Prequel (TV) Bleach: Sennen Kessen-hen - Ket...
# ..                                                 ...
# 241                                                 []
# 242                                                 []
# 243                                                 []
# 244                                                 []
# 245                                                 []
#
#                                                  Title  \
# 0                                             Dandadan
# 1     Re:Zero kara Hajimeru Isekai Seikatsu 3rd Season
# 2                             Blue Lock vs. U-20 Japan
# 3                                              Uzumaki
# 4              Bleach: Sennen Kessen-hen - Soukoku-tan
# ..                                                 ...
# 241                     Delico's Nursery: Ikuji Nisshi
# 242  Tousouchuu: Great Mission - Maika to Rabbi no ...
# 243     Love Live! Superstar!! 3rd Season (TV Special)
# 244                       YouTuNya: Christmas tte Mita
# 245                                        Ana no Naka
#
#                                               Synonyms  \
# 0                                                  NaN
# 1    Re: Life in a different world from zero 3rd Se...
# 2                                 Blue Lock 2nd Season
# 3                                           The Spiral
# 4           Bleach: Thousand-Year Blood War Arc Part 3
# ..                                                 ...
# 241  Delico's Nursery Recap, Delico's Nursery Episo...
# 242  Tousouchuu: Great Mission Recap, Tousouchuu: G...
# 243                                                NaN
# 244                   YouTuNya Christmas Tokubetsu-hen
# 245                                                NaN
#
#                                           Themes          Genre  \
# 0                                            NaN            NaN
# 1     ['Isekai', 'Psychological', 'Time Travel']            NaN
# 2                                            NaN     ['Sports']
# 3                                            NaN            NaN
# 4                                            NaN            NaN
# ..                                           ...            ...
# 241  ['Childcare', 'Organized Crime', 'Vampire']            NaN
# 242                                          NaN            NaN
# 243                                          NaN            NaN
# 244                                          NaN     ['Comedy']
# 245                                          NaN  ['Adventure']
#
#                     Theme German Spanish Demographics French
# 0                     NaN    NaN     NaN          NaN    NaN
# 1                     NaN    NaN     NaN          NaN    NaN
# 2         ['Team Sports']    NaN     NaN          NaN    NaN
# 3       ['Psychological']    NaN     NaN          NaN    NaN
# 4                     NaN    NaN     NaN          NaN    NaN
# ..                    ...    ...     ...          ...    ...
# 241                   NaN    NaN     NaN          NaN    NaN
# 242  ['High Stakes Game']    NaN     NaN          NaN    NaN
# 243    ['Idols (Female)']    NaN     NaN          NaN    NaN
# 244                   NaN    NaN     NaN          NaN    NaN
# 245                   NaN    NaN     NaN          NaN    NaN
#
# [246 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['Japanese', 'English', 'Type', 'Episodes', 'Status', 'Aired',
#        'Premiered', 'Broadcast', 'Producers', 'Licensors', 'Studios', 'Source',
#        'Genres', 'Demographic', 'Duration', 'Rating', 'Score', 'Ranked',
#        'Popularity', 'Members', 'Favorites', 'Scorers', 'Synopsis',
#        'Related_Entries', 'Title', 'Synonyms', 'Themes', 'Genre', 'Theme',
#        'German', 'Spanish', 'Demographics', 'French'],
#       dtype='object')

# %%
df.Type.value_counts()
# Out:
# Type
# ['TV']            134
# ['ONA']            77
# ['Movie']          17
# ['OVA']             9
# ['TV Special']      8
# ['Special']         1
# Name: count, dtype: int64
